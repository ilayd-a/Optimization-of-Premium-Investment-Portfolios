# %% [markdown]
# This is the notebook to define the 8 Qubit QAOA in Bloqade SDK using python:

# %% [markdown]
# We need Hc, which is the 8 values that come out of H function after passing it the feateures variables

# %% [markdown]
# We need Hm, which we define it, a common way to define it is using RX gate (rotations in X)

# %% [markdown]
# We need to define the QAOA algorithm, that in essence is:
# - Starting the 8 qubits
# - Apply Hadamard gates to create equal superposition
# - Apply Hc part of the circuit which would be quantum gates
# - Apply Hm part of the circuit which would be quantum gates
# - Measure it

# %% [markdown]
# ** After measurement you get a bitstring **

# %% [markdown]
# After having your QAOA defined, we also have to define auxiliar functions in python to make x quantity of shots per circuit, define the probability of a bitstring, the function to calculate energy/cost of a bitstring, a classical optimizer to update parameters from QAOA, run the circuit again, so we need the function to run the circuit

# %% [markdown]
# **pip installs [ I DO NOT USE THESE, USE A PYTHON ENVIRONMENT USING POWERSHELL, CHECK THE CELL BELOW]**

# %%
# pip install -q bloqade
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# import sys
# !{sys.executable} -m pip install -U lark
# Out:
# Requirement already satisfied: lark in c:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.3.1)

# %%
# from bloqade import tsim
# print("tsim ok")

# %% [markdown]
# **INSTALL using powershell dependencies**

# %% [markdown]
# ## Environment setup (PowerShell, one-time)
#
# This notebook is intended to run in the `bloqade312` environment on Windows using VS Code `.ipynb`.
#
# ### 1) Create and activate the environment
# Run these commands in **PowerShell**:
#
# ```powershell
# py install 3.12
# py -3.12 -m venv C:\bloqade312
# C:\bloqade312\Scripts\Activate.ps1

# %% [markdown]
# ## 2) Install required packages
#
# ```powershell
# python -m pip install --upgrade pip
# pip install bloqade ipykernel scipy numpy
# python -m ipykernel install --user --name bloqade312 --display-name "Python (bloqade312)"
# ```
#
# ## 3) In VS Code
#
# Open the notebook and select the kernel:
#
# `Python (bloqade312)`

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# c:\bloqade312\Scripts\python.exe
# 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]

# %%
import math
from typing import Any
import numpy as np
import kirin
from kirin.dialects import ilist
from bloqade import qasm2
from bloqade import squin, tsim
from bloqade.types import MeasurementResult, Qubit
from kirin.dialects.ilist import IList

# %%
from bloqade import squin
print("squin ok")
# Out:
# squin ok

# %%
from bloqade import tsim
print("tsim ok")
# Out:
# tsim ok

# %%
from bloqade.types import MeasurementResult, Qubit
from kirin.dialects.ilist import IList
from typing import Any

Register = IList[Qubit, Any]
Measurement = IList[MeasurementResult, Any]

print("types ok")
# Out:
# types ok

# %%
"""from bloqade import squin
from bloqade.types import MeasurementResult, Qubit
from kirin.dialects.ilist import IList
from typing import Any

Measurement = IList[MeasurementResult, Any]

@squin.kernel
def bell() -> Measurement:
    q = squin.qalloc(2)
    squin.h(q[0])
    squin.cx(q[0], q[1])
    bits = squin.broadcast.measure(q)
    return bits

print("kernel created")"""

# %% [markdown]
# **Imports**

# %%
import math
from typing import Any
import numpy as np

from bloqade import qasm2
from bloqade import squin, tsim
from bloqade.types import MeasurementResult, Qubit
from kirin.dialects.ilist import IList

pi = math.pi

Register = IList[Qubit, Any]
Measurement = IList[MeasurementResult, Any]

print("squin/tsim imports worked")
# Out:
# squin/tsim imports worked

# %% [markdown]
# **Global variables from Hamiltonian function we produced**

# %% [markdown]
# With these variables produced already, we do not need to use the dataset again or touch it in this ipynb because we already produced the hamiltonian cost on the variables we are using.

# %% [markdown]
# The ground truth was produced by brute forcing the 256 combinations and checking the best one, since is easy for a classical computer to do that

# %%
n_qubits = 8

qubit_labels = [
    "A004_LSB", "A004_MSB",
    "A047_LSB", "A047_MSB",
    "A026_LSB", "A026_MSB",
    "A017_LSB", "A017_MSB",
]

# Constant offset is irrelevant for QAOA optimization because it does not change
# which bitstring minimizes the objective.
c0 = 0.0

# FIXED H terms
# Local fields h_i for H_C = sum_i h_i Z_i + sum_{i<j} J_ij Z_i Z_j
h_terms = [
    (0, -0.019730),
    (1, -0.039461),
    (2, -0.014721),
    (3, -0.029441),
    (4, -0.028659),
    (5, -0.057318),
    (6, -0.047267),
    (7, -0.094534),
]

# FIXED J terms
J_terms = [
    (0, 1, 0.007132),
    (0, 2, 0.002667),
    (0, 3, 0.005334),
    (0, 4, 0.005334),
    (0, 5, 0.010667),
    (0, 6, 0.008889),
    (0, 7, 0.017778),
    (1, 2, 0.005334),
    (1, 3, 0.010667),
    (1, 4, 0.010667),
    (1, 5, 0.021335),
    (1, 6, 0.017778),
    (1, 7, 0.035555),
    (2, 3, 0.004005),
    (2, 4, 0.004000),
    (2, 5, 0.008000),
    (2, 6, 0.006667),
    (2, 7, 0.013335),
    (3, 4, 0.008000),
    (3, 5, 0.016000),
    (3, 6, 0.013335),
    (3, 7, 0.026665),
    (4, 5, 0.016005),
    (4, 6, 0.013335),
    (4, 7, 0.026667),
    (5, 6, 0.026667),
    (5, 7, 0.053335),
    (6, 7, 0.044450),
]


# Remains the same even after fix
ground_truth_bitstring = "11011110"

# %% [markdown]
# **First we are going to convert the Hamiltonian data to arrays**

# %%
import numpy as np

# Build dense h vector and J matrix from the term lists
h8 = np.zeros(n_qubits, dtype=float)
J8 = np.zeros((n_qubits, n_qubits), dtype=float)

for i, hi in h_terms:
    h8[i] = hi

for i, j, Jij in J_terms:
    J8[i, j] = Jij
    J8[j, i] = Jij

ising_offset = 0.0

print("h8:")
print(h8)
print("\nJ8:")
print(J8)
# Out:
# h8:
# [-0.01973  -0.039461 -0.014721 -0.029441 -0.028659 -0.057318 -0.047267
#  -0.094534]
#
# J8:
# [[0.       0.007132 0.002667 0.005334 0.005334 0.010667 0.008889 0.017778]
#  [0.007132 0.       0.005334 0.010667 0.010667 0.021335 0.017778 0.035555]
#  [0.002667 0.005334 0.       0.004005 0.004    0.008    0.006667 0.013335]
#  [0.005334 0.010667 0.004005 0.       0.008    0.016    0.013335 0.026665]
#  [0.005334 0.010667 0.004    0.008    0.       0.016005 0.013335 0.026667]
#  [0.010667 0.021335 0.008    0.016    0.016005 0.       0.026667 0.053335]
#  [0.008889 0.017778 0.006667 0.013335 0.013335 0.026667 0.       0.04445 ]
#  [0.017778 0.035555 0.013335 0.026665 0.026667 0.053335 0.04445  0.      ]]

# %% [markdown]
# **Classical Icing Energy**

# %%
def ising_energy_from_x_list(x_list, h, J, ising_offset=0.0):
    # Use the convention x = (1 + s)/2, so s = 2x - 1
    s = np.array([2 * int(bit) - 1 for bit in x_list], dtype=float)

    energy = ising_offset

    for i in range(len(h)):
        energy += h[i] * s[i]

    for i in range(J.shape[0]):
        for j in range(i + 1, J.shape[1]):
            energy += J[i, j] * s[i] * s[j]

    return float(energy)

# %% [markdown]
# **Helper to convert bitstring to x-list**

# %%
def bitstring_to_x_list(bitstring):
    return [int(b) for b in bitstring]

# %% [markdown]
# **Decode 2 bits per asset**

# %%
def decode_lots_from_bitstring(bitstring):
    """
    Decode 8 qubits into 4 asset lot values using:
    lot = LSB + 2 * MSB
    """
    bits = [int(b) for b in bitstring]
    lots = []

    for k in range(0, len(bits), 2):
        lsb = bits[k]
        msb = bits[k + 1]
        lot = lsb + 2 * msb
        lots.append(lot)

    return lots

# %% [markdown]
# **Verify the portfolio**

# %%
decoded_lots = decode_lots_from_bitstring(ground_truth_bitstring)
print("Decoded lots from ground-truth bitstring:", decoded_lots)
# Out:
# Decoded lots from ground-truth bitstring: [3, 2, 3, 1]

# %% [markdown]
# **Test the ground truth**

# %%
ground_truth_x = [1, 1, 0, 1, 1, 1, 1, 0]

print("Ground-truth x:", ground_truth_x)
print("Ground-truth lots:", decode_lots_from_bitstring("".join(str(b) for b in ground_truth_x)))
print("Ground-truth corrected Ising energy:", ising_energy_from_x_list(ground_truth_x, h8, J8, ising_offset))
# Out:
# Ground-truth x: [1, 1, 0, 1, 1, 1, 1, 0]
# Ground-truth lots: [3, 2, 3, 1]
# Ground-truth corrected Ising energy: -0.14326400000000006

# %% [markdown]
# **Brute-force classical check over all 256 bitstrings**

# %%
def x_list_to_lots(x_list):
    lots = []
    for k in range(0, len(x_list), 2):
        lsb = x_list[k]
        msb = x_list[k + 1]
        lot = lsb + 2 * msb
        lots.append(lot)
    return lots

all_results_rebuilt = []

for num in range(2 ** n_qubits):
    x_list = [(num >> i) & 1 for i in range(n_qubits)]
    e_ising = ising_energy_from_x_list(x_list, h8, J8, ising_offset)

    all_results_rebuilt.append({
        "x": x_list,
        "lots": x_list_to_lots(x_list),
        "ising_energy": e_ising
    })

all_results_rebuilt = sorted(all_results_rebuilt, key=lambda r: r["ising_energy"])

print("Top 15 solutions ranked by corrected Ising energy:\n")
for rank, r in enumerate(all_results_rebuilt[:15], start=1):
    print(f"{rank:2d}. x={r['x']}  lots={r['lots']}  Ising={r['ising_energy']:.8f}")
# Out:
# Top 15 solutions ranked by corrected Ising energy:
#
#  1. x=[1, 1, 0, 1, 1, 1, 1, 0]  lots=[3, 2, 3, 1]  Ising=-0.14326400
#  2. x=[0, 1, 1, 1, 1, 1, 1, 0]  lots=[2, 3, 3, 1]  Ising=-0.14306000
#  3. x=[1, 1, 1, 1, 0, 1, 1, 0]  lots=[3, 3, 2, 1]  Ising=-0.14206000
#  4. x=[1, 1, 1, 1, 1, 0, 0, 1]  lots=[3, 3, 1, 2]  Ising=-0.14195000
#  5. x=[1, 1, 0, 1, 1, 0, 0, 1]  lots=[3, 2, 1, 2]  Ising=-0.14185600
#  6. x=[0, 1, 0, 1, 0, 1, 0, 1]  lots=[2, 2, 2, 2]  Ising=-0.14108200
#  7. x=[1, 0, 1, 1, 0, 1, 0, 1]  lots=[1, 3, 2, 2]  Ising=-0.14082800
#  8. x=[1, 1, 1, 0, 0, 0, 1, 1]  lots=[3, 1, 0, 3]  Ising=-0.14071800
#  9. x=[1, 1, 1, 0, 1, 1, 1, 0]  lots=[3, 1, 3, 1]  Ising=-0.14050000
# 10. x=[1, 1, 1, 0, 0, 1, 0, 1]  lots=[3, 1, 2, 2]  Ising=-0.14038400
# 11. x=[1, 1, 0, 0, 0, 1, 0, 1]  lots=[3, 0, 2, 2]  Ising=-0.14027000
# 12. x=[0, 1, 1, 1, 1, 0, 0, 1]  lots=[2, 3, 1, 2]  Ising=-0.13986800
# 13. x=[0, 1, 1, 1, 0, 0, 1, 1]  lots=[2, 3, 0, 3]  Ising=-0.13972600
# 14. x=[0, 1, 0, 1, 0, 0, 1, 1]  lots=[2, 2, 0, 3]  Ising=-0.13963200
# 15. x=[0, 1, 0, 0, 1, 1, 0, 1]  lots=[2, 0, 3, 2]  Ising=-0.13949400

# %% [markdown]
# **Check the rank of the known ground truth**

# %%
gt_rank = None

for idx, r in enumerate(all_results_rebuilt):
    if r["x"] == ground_truth_x:
        gt_rank = idx + 1
        print("Ground-truth entry found:")
        print(r)
        break

print("\nGround-truth rank under corrected Ising evaluation:", gt_rank)
# Out:
# Ground-truth entry found:
# {'x': [1, 1, 0, 1, 1, 1, 1, 0], 'lots': [3, 2, 3, 1], 'ising_energy': -0.14326400000000006}
#
# Ground-truth rank under corrected Ising evaluation: 1

# %% [markdown]
# # We actually create QAOA now as a bloqade quantum circuit

# %% [markdown]
# Import the simulator

# %%
from bloqade.pyqrack import StackMemorySimulator

# %% [markdown]
# **Build the QAOA algorithm on Bloqade**

# %%
def build_qaoa_ising_kernel(n_qubits, h_terms, J_terms):
    @qasm2.extended
    def kernel(gamma: ilist.IList[float, Any], beta: ilist.IList[float, Any]):
        q = qasm2.qreg(n_qubits)

        # Initialize the register in the |+> state
        for i in range(n_qubits):
            qasm2.h(q[i])

        # Apply p QAOA layers
        for layer in range(len(gamma)):
            g = gamma[layer]
            b = beta[layer]

            # Single-qubit Z terms
            for k in range(len(h_terms)):
                term = h_terms[k]
                i = term[0]
                hi = term[1]
                qasm2.rz(q[i], 2.0 * g * hi)

            # Two-qubit ZZ terms
            for k in range(len(J_terms)):
                term = J_terms[k]
                i = term[0]
                j = term[1]
                Jij = term[2]

                qasm2.cx(q[i], q[j])
                qasm2.rz(q[j], 2.0 * g * Jij)
                qasm2.cx(q[i], q[j])

            # Mixer layer
            for i in range(n_qubits):
                qasm2.rx(q[i], 2.0 * b)

        return q

    return kernel

# %% [markdown]
# **Create the Kernel**

# %%
kernel = build_qaoa_ising_kernel(n_qubits, h_terms, J_terms)
print(kernel)
# Out:
# Method("kernel")

# %%
print(kernel)
print(type(kernel))
# Out:
# Method("kernel")
# <class 'kirin.ir.method.Method'>

# %% [markdown]
# **Choose initial QAOA parameters**

# %%
# P stands for the depth of the circuit, how many times we repeat the gates
p = 1

gamma_init = [0.3] * p
beta_init = [0.2] * p

# %% [markdown]
# **wrap in main and emit QASM**

# %%
@qasm2.extended
def main():
    return kernel(gamma_init, beta_init)

# %% [markdown]
# **print the generated circuit**

# %%
target = qasm2.emit.QASM2()
ast = target.emit(main)
qasm2.parse.pprint(ast)
# Out:
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg q[8];
# h q[0];
# h q[1];
# h q[2];
# h q[3];
# h q[4];
# h q[5];
# h q[6];
# h q[7];
# rz (-0.011838) q[0];
# rz (-0.023676600000000003) q[1];
# rz (-0.0088326) q[2];
# rz (-0.0176646) q[3];
# rz (-0.0171954) q[4];
# rz (-0.0343908) q[5];
# rz (-0.028360200000000002) q[6];
# rz (-0.056720400000000004) q[7];
# CX q[0], q[1];
# rz (0.0042792) q[1];
# CX q[0], q[1];
# CX q[0], q[2];
# rz (0.0016002) q[2];
# CX q[0], q[2];
# CX q[0], q[3];
# rz (0.0032004) q[3];
# CX q[0], q[3];
# CX q[0], q[4];
# rz (0.0032004) q[4];
# CX q[0], q[4];
# CX q[0], q[5];
# rz (0.006400199999999999) q[5];
# CX q[0], q[5];
# CX q[0], q[6];
# rz (0.005333399999999999) q[6];
# CX q[0], q[6];
# CX q[0], q[7];
# rz (0.010666799999999999) q[7];
# CX q[0], q[7];
# CX q[1], q[2];
# rz (0.0032004) q[2];
# CX q[1], q[2];
# CX q[1], q[3];
# rz (0.006400199999999999) q[3];
# CX q[1], q[3];
# CX q[1], q[4];
# rz (0.006400199999999999) q[4];
# CX q[1], q[4];
# CX q[1], q[5];
# rz (0.012801) q[5];
# CX q[1], q[5];
# CX q[1], q[6];
# rz (0.010666799999999999) q[6];
# CX q[1], q[6];
# CX q[1], q[7];
# rz (0.021333) q[7];
# CX q[1], q[7];
# CX q[2], q[3];
# rz (0.0024029999999999998) q[3];
# CX q[2], q[3];
# CX q[2], q[4];
# rz (0.0024) q[4];
# CX q[2], q[4];
# CX q[2], q[5];
# rz (0.0048) q[5];
# CX q[2], q[5];
# CX q[2], q[6];
# rz (0.0040002) q[6];
# CX q[2], q[6];
# CX q[2], q[7];
# rz (0.008001) q[7];
# CX q[2], q[7];
# CX q[3], q[4];
# rz (0.0048) q[4];
# CX q[3], q[4];
# CX q[3], q[5];
# rz (0.0096) q[5];
# CX q[3], q[5];
# CX q[3], q[6];
# rz (0.008001) q[6];
# CX q[3], q[6];
# CX q[3], q[7];
# rz (0.015999) q[7];
# CX q[3], q[7];
# CX q[4], q[5];
# rz (0.009602999999999999) q[5];
# CX q[4], q[5];
# CX q[4], q[6];
# rz (0.008001) q[6];
# CX q[4], q[6];
# CX q[4], q[7];
# rz (0.0160002) q[7];
# CX q[4], q[7];
# CX q[5], q[6];
# rz (0.0160002) q[6];
# CX q[5], q[6];
# CX q[5], q[7];
# rz (0.032001) q[7];
# CX q[5], q[7];
# CX q[6], q[7];
# rz (0.026670000000000003) q[7];
# CX q[6], q[7];
# rx (0.4) q[0];
# rx (0.4) q[1];
# rx (0.4) q[2];
# rx (0.4) q[3];
# rx (0.4) q[4];
# rx (0.4) q[5];
# rx (0.4) q[6];
# rx (0.4) q[7];

# %% [markdown]
# **run the circuit and get the state vector**

# %%
sim = StackMemorySimulator(min_qubits=n_qubits)

ket = sim.state_vector(main)

print("State vector length:", len(ket))
print("Number of qubits:", n_qubits)
# Out:
# State vector length: 256
# Number of qubits: 8

# %% [markdown]
# **Convert the state vector into probabilities**

# %%
probs = np.abs(np.array(ket))**2

print("Probability sum:", probs.sum())
# Out:
# Probability sum: 1.0000000064000112

# %% [markdown]
# **helper to show the most likely bitstrings**

# %%
def index_to_bitstring(idx, n):
    return format(idx, f"0{n}b")

top_k = 15
top_indices = np.argsort(probs)[::-1][:top_k]

print(f"Top {top_k} most likely computational basis states:\n")
for rank, idx in enumerate(top_indices, start=1):
    bitstring = index_to_bitstring(idx, n_qubits)
    prob = probs[idx]
    print(f"{rank:2d}. bitstring={bitstring}   prob={prob:.8f}")
# Out:
# Top 15 most likely computational basis states:
#
#  1. bitstring=11111111   prob=0.00503798
#  2. bitstring=11111011   prob=0.00482711
#  3. bitstring=11111110   prob=0.00476186
#  4. bitstring=11101111   prob=0.00464129
#  5. bitstring=11110111   prob=0.00463960
#  6. bitstring=11111010   prob=0.00458252
#  7. bitstring=11111101   prob=0.00452577
#  8. bitstring=11101011   prob=0.00447629
#  9. bitstring=11110011   prob=0.00447469
# 10. bitstring=11101110   prob=0.00442547
# 11. bitstring=10111111   prob=0.00442532
# 12. bitstring=11110110   prob=0.00442385
# 13. bitstring=11111001   prob=0.00437450
# 14. bitstring=00000000   prob=0.00435507
# 15. bitstring=11100111   prob=0.00433081

# %% [markdown]
# **check the ground-truth probability**

# %%
ground_truth_bitstring = "11011110"
gt_index = int(ground_truth_bitstring, 2)

print("Ground-truth bitstring:", ground_truth_bitstring)
print("Ground-truth probability:", probs[gt_index])
# Out:
# Ground-truth bitstring: 11011110
# Ground-truth probability: 0.004163693891188598

# %% [markdown]
# **Compute ising energy for the most likely bitstrings**

# %%
def bitstring_to_x_list(bitstring):
    return [int(b) for b in bitstring]

print("Top states with Ising energy:\n")
for rank, idx in enumerate(top_indices, start=1):
    bitstring = index_to_bitstring(idx, n_qubits)
    x_list = bitstring_to_x_list(bitstring)
    energy = ising_energy_from_x_list(x_list, h8, J8, ising_offset)
    print(f"{rank:2d}. bitstring={bitstring}   prob={probs[idx]:.8f}   energy={energy:.8f}")
# Out:
# Top states with Ising energy:
#
#  1. bitstring=11111111   prob=0.00503798   energy=0.10847200
#  2. bitstring=11111011   prob=0.00482711   energy=-0.08091000
#  3. bitstring=11111110   prob=0.00476186   energy=-0.13803000
#  4. bitstring=11101111   prob=0.00464129   energy=-0.00065800
#  5. bitstring=11110111   prob=0.00463960   energy=-0.00222600
#  6. bitstring=11111010   prob=0.00458252   energy=-0.11407200
#  7. bitstring=11111101   prob=0.00452577   energy=-0.05923600
#  8. bitstring=11101011   prob=0.00447629   energy=-0.12604000
#  9. bitstring=11110011   prob=0.00447469   energy=-0.12758800
# 10. bitstring=11101110   prob=0.00442547   energy=-0.14050000
# 11. bitstring=10111111   prob=0.00442532   energy=-0.02954200
# 12. bitstring=11110110   prob=0.00442385   energy=-0.14206000
# 13. bitstring=11111001   prob=0.00437450   energy=-0.14195000
# 14. bitstring=00000000   prob=0.00435507   energy=0.77073400
# 15. bitstring=11100111   prob=0.00433081   energy=-0.07935600

# %% [markdown]
# NO LE ENTIENDO ES CHAT: Cell 8 — compare direct and reversed bitstring conventions

# %%
ground_truth_x = [1, 1, 0, 1, 1, 1, 1, 0]

gt_direct = "".join(str(b) for b in ground_truth_x)
gt_reversed = gt_direct[::-1]

print("Direct ground-truth bitstring:  ", gt_direct, "prob =", probs[int(gt_direct, 2)])
print("Reversed ground-truth bitstring:", gt_reversed, "prob =", probs[int(gt_reversed, 2)])
# Out:
# Direct ground-truth bitstring:   11011110 prob = 0.004163693891188598
# Reversed ground-truth bitstring: 01111011 prob = 0.003938217110797988

# %% [markdown]
# **Everything works natural and good now, the circuit is working, now we start doing the classical optimization of the 2 variatonal parameters of the circuit, gamma and beta, so we can start getting good results**

# %% [markdown]
# Right now i have hard-coded gamma and beta

# %%
def build_main_from_params(gamma_vals, beta_vals):
    @qasm2.extended
    def main():
        return kernel(gamma_vals, beta_vals)
    return main

# %%
def expected_ising_energy(gamma_vals, beta_vals):
    main = build_main_from_params(gamma_vals, beta_vals)
    ket = sim.state_vector(main)
    probs = np.abs(np.array(ket)) ** 2

    exp_energy = 0.0
    for idx in range(2 ** n_qubits):
        bitstring = format(idx, f"0{n_qubits}b")
        x_list = [int(b) for b in bitstring]
        energy = ising_energy_from_x_list(x_list, h8, J8, ising_offset)
        exp_energy += probs[idx] * energy

    return float(exp_energy)

# %%
print("Expected energy at gamma=0.3, beta=0.2:",
      expected_ising_energy([0.3], [0.2]))
# Out:
# Expected energy at gamma=0.3, beta=0.2: -0.0005120791314177489

# %%
from scipy.optimize import minimize
eval_history = []

def objective_theta(theta):
    gamma_vals = [theta[0]]
    beta_vals  = [theta[1]]

    value = expected_ising_energy(gamma_vals, beta_vals)
    eval_history.append((theta[0], theta[1], value))

    print(f"gamma={theta[0]:.6f}, beta={theta[1]:.6f}, expected_energy={value:.8f}")
    return value

# %% [markdown]
# **CLASSICAL OPTIMIZER to update params on variational quantum circuit**

# %%
theta0 = np.array([0.3, 0.2], dtype=float)

result = minimize(
    objective_theta,
    theta0,
    method="COBYLA",
    options={"maxiter": 1000, "rhobeg": 0.2}
)

print("\nOptimization finished")
print("Best theta:", result.x)
print("Best expected energy:", result.fun)
print("Success:", result.success)
print("Message:", result.message)
# Out:
# gamma=0.300000, beta=0.200000, expected_energy=-0.00051210
# gamma=0.500000, beta=0.200000, expected_energy=-0.00078981
# gamma=0.500000, beta=0.400000, expected_energy=-0.00266959
# gamma=0.529230, beta=0.597852, expected_energy=-0.00634375
# gamma=0.362535, beta=0.961463, expected_energy=-0.00901344
# gamma=0.584743, beta=1.294065, expected_energy=-0.01099424
# gamma=0.513267, beta=1.687627, expected_energy=0.00473192
# gamma=0.759402, beta=1.196626, expected_energy=-0.01688510
# gamma=0.941961, beta=1.114942, expected_energy=-0.02193839
# gamma=1.323981, beta=0.996363, expected_energy=-0.02863145
# gamma=1.693578, beta=1.149328, expected_energy=-0.03515564
# gamma=2.493535, beta=1.157622, expected_energy=-0.04601625
# gamma=3.773671, beta=2.117440, expected_energy=0.12833285
# gamma=2.555265, beta=0.360007, expected_energy=-0.00215332
# gamma=2.583962, beta=1.547267, expected_energy=-0.00450682
# gamma=2.520068, beta=0.959390, expected_energy=-0.04087605
# gamma=2.592651, beta=1.170889, expected_energy=-0.04691732
# gamma=2.633197, beta=1.366736, expected_energy=-0.03351569
# gamma=2.617774, beta=1.074096, expected_energy=-0.04685266
# gamma=2.589334, beta=1.195668, expected_energy=-0.04623040
# gamma=2.614397, beta=1.125865, expected_energy=-0.04754735
# gamma=2.652010, beta=1.092922, expected_energy=-0.04758558
# gamma=2.639215, beta=1.077551, expected_energy=-0.04713744
# gamma=2.659696, beta=1.086525, expected_energy=-0.04753246
# gamma=2.660914, beta=1.110831, expected_energy=-0.04792614
# gamma=2.675679, beta=1.148006, expected_energy=-0.04813265
# gamma=2.641053, beta=1.168032, expected_energy=-0.04750788
# gamma=2.695622, beta=1.146494, expected_energy=-0.04835073
# gamma=2.715509, beta=1.148616, expected_energy=-0.04854159
# gamma=2.753737, beta=1.160391, expected_energy=-0.04881925
# gamma=2.782658, beta=1.234980, expected_energy=-0.04671742
# gamma=2.772033, beta=1.124820, expected_energy=-0.04911711
# gamma=2.808217, beta=1.107770, expected_energy=-0.04927597
# gamma=2.811116, beta=1.067875, expected_energy=-0.04833709
# gamma=2.819104, beta=1.124546, expected_energy=-0.04955832
# gamma=2.832328, beta=1.139551, expected_energy=-0.04973156
# gamma=2.851217, beta=1.146124, expected_energy=-0.04989855
# gamma=2.882781, beta=1.170695, expected_energy=-0.04996432
# gamma=2.909722, beta=1.141128, expected_energy=-0.05045258
# gamma=2.938314, beta=1.113155, expected_energy=-0.05048626
# gamma=2.953144, beta=1.126573, expected_energy=-0.05077296
# gamma=2.982748, beta=1.153473, expected_energy=-0.05108504
# gamma=3.020965, beta=1.165283, expected_energy=-0.05133501
# gamma=3.065554, beta=1.231705, expected_energy=-0.04976357
# gamma=3.038677, beta=1.129418, expected_energy=-0.05151824
# gamma=3.077647, beta=1.120402, expected_energy=-0.05172394
# gamma=3.145918, beta=1.078699, expected_energy=-0.05111659
# gamma=3.091616, beta=1.157883, expected_energy=-0.05201592
# gamma=3.122511, beta=1.183290, expected_energy=-0.05196528
# gamma=3.077783, beta=1.172328, expected_energy=-0.05175479
# gamma=3.097200, beta=1.149588, expected_energy=-0.05208894
# gamma=3.102121, beta=1.140883, expected_energy=-0.05211430
# gamma=3.100373, beta=1.131037, expected_energy=-0.05203244
# gamma=3.104298, beta=1.142113, expected_energy=-0.05213683
# gamma=3.109154, beta=1.143303, expected_energy=-0.05218047
# gamma=3.118958, beta=1.145276, expected_energy=-0.05226560
# gamma=3.138680, beta=1.148594, expected_energy=-0.05243086
# gamma=3.178534, beta=1.152011, expected_energy=-0.05275281
# gamma=3.257231, beta=1.137632, expected_energy=-0.05329239
# gamma=3.394912, beta=1.219143, expected_energy=-0.05323548
# gamma=3.295676, beta=1.067475, expected_energy=-0.05151496
# gamma=3.271920, beta=1.174837, expected_energy=-0.05335725
# gamma=3.291742, beta=1.172175, expected_energy=-0.05354445
# gamma=3.330926, beta=1.164137, expected_energy=-0.05390612
# gamma=3.409669, beta=1.150013, expected_energy=-0.05446794
# gamma=3.563178, beta=1.195126, expected_energy=-0.05522674
# gamma=3.692120, beta=1.100395, expected_energy=-0.05488562
# gamma=3.591340, beta=1.270005, expected_energy=-0.05200219
# gamma=3.544458, beta=1.202166, expected_energy=-0.05493198
# gamma=3.562810, beta=1.155128, expected_energy=-0.05550738
# gamma=3.597912, beta=1.135949, expected_energy=-0.05548584
# gamma=3.552097, beta=1.138239, expected_energy=-0.05525757
# gamma=3.558588, beta=1.157806, expected_energy=-0.05549363
# gamma=3.569857, beta=1.162223, expected_energy=-0.05557800
# gamma=3.578041, beta=1.167969, expected_energy=-0.05562927
# gamma=3.596371, beta=1.159968, expected_energy=-0.05574110
# gamma=3.616365, beta=1.160435, expected_energy=-0.05586751
# gamma=3.656250, beta=1.163473, expected_energy=-0.05612223
# gamma=3.735865, beta=1.171313, expected_energy=-0.05660788
# gamma=3.892480, beta=1.138578, expected_energy=-0.05704816
# gamma=3.960759, beta=1.283278, expected_energy=-0.05365626
# gamma=3.885759, beta=1.058861, expected_energy=-0.05319830
# gamma=3.912409, beta=1.136898, expected_energy=-0.05709522
# gamma=3.917713, beta=1.176545, expected_energy=-0.05762882
# gamma=3.927995, beta=1.215200, expected_energy=-0.05713178
# gamma=3.935964, beta=1.168367, expected_energy=-0.05770436
# gamma=3.934810, beta=1.158434, expected_energy=-0.05761077
# gamma=3.938448, beta=1.168078, expected_energy=-0.05771536
# gamma=3.941084, beta=1.172327, expected_energy=-0.05774692
# gamma=3.944830, beta=1.175638, expected_energy=-0.05777193
# gamma=3.945166, beta=1.185632, expected_energy=-0.05774421
# gamma=3.949580, beta=1.174078, expected_energy=-0.05779479
# gamma=3.953575, beta=1.171071, expected_energy=-0.05780661
# gamma=3.953061, beta=1.166097, expected_energy=-0.05777574
# gamma=3.954819, beta=1.170942, expected_energy=-0.05781235
# gamma=3.956510, beta=1.172784, expected_energy=-0.05782738
# gamma=3.960573, beta=1.175698, expected_energy=-0.05785362
# gamma=3.963188, beta=1.185350, expected_energy=-0.05784311
# gamma=3.965227, beta=1.173872, expected_energy=-0.05787465
# gamma=3.969580, beta=1.171411, expected_energy=-0.05788888
# gamma=3.972683, beta=1.167491, expected_energy=-0.05788277
# gamma=3.971349, beta=1.173178, expected_energy=-0.05790391
# gamma=3.972954, beta=1.175094, expected_energy=-0.05791640
# gamma=3.975537, beta=1.179375, expected_energy=-0.05793002
# gamma=3.973351, beta=1.183872, expected_energy=-0.05790498
# gamma=3.977985, beta=1.178868, expected_energy=-0.05794330
# gamma=3.980485, beta=1.178831, expected_energy=-0.05795626
# gamma=3.985481, beta=1.179036, expected_energy=-0.05798175
# gamma=3.995447, beta=1.179859, expected_energy=-0.05803189
# gamma=4.015190, beta=1.183050, expected_energy=-0.05812564
# gamma=4.048397, beta=1.160749, expected_energy=-0.05817105
# gamma=4.076523, beta=1.189191, expected_energy=-0.05840708
# gamma=4.133067, beta=1.245784, expected_energy=-0.05716544
# gamma=4.086436, beta=1.150439, expected_energy=-0.05815510
# gamma=4.086211, beta=1.191669, expected_energy=-0.05843790
# gamma=4.090274, beta=1.211252, expected_energy=-0.05815949
# gamma=4.090377, beta=1.182578, expected_energy=-0.05850044
# gamma=4.097114, beta=1.175188, expected_energy=-0.05852113
# gamma=4.105618, beta=1.180449, expected_energy=-0.05857383
# gamma=4.115028, beta=1.183831, expected_energy=-0.05861693
# gamma=4.134930, beta=1.181846, expected_energy=-0.05871200
# gamma=4.174765, beta=1.178225, expected_energy=-0.05888568
# gamma=4.244678, beta=1.217112, expected_energy=-0.05882166
# gamma=4.190995, beta=1.141665, expected_energy=-0.05832501
# gamma=4.183905, beta=1.182282, expected_energy=-0.05893618
# gamma=4.182468, beta=1.202231, expected_energy=-0.05880024
# gamma=4.191904, beta=1.176280, expected_energy=-0.05895154
# gamma=4.200015, beta=1.182129, expected_energy=-0.05900789
# gamma=4.215925, beta=1.194248, expected_energy=-0.05904512
# gamma=4.232932, beta=1.183725, expected_energy=-0.05915451
# gamma=4.266550, beta=1.162049, expected_energy=-0.05908634
# gamma=4.240800, beta=1.202112, expected_energy=-0.05908233
# gamma=4.237529, beta=1.181758, expected_energy=-0.05917079
# gamma=4.240766, beta=1.172296, expected_energy=-0.05912621
# gamma=4.238513, beta=1.184056, expected_energy=-0.05917897
# gamma=4.243149, beta=1.185928, expected_energy=-0.05919956
# gamma=4.251903, beta=1.190762, expected_energy=-0.05922782
# gamma=4.258725, beta=1.198074, expected_energy=-0.05921027
# gamma=4.255109, beta=1.186926, expected_energy=-0.05925105
# gamma=4.257263, beta=1.182413, expected_energy=-0.05925662
# gamma=4.253519, beta=1.179099, expected_energy=-0.05922850
# gamma=4.258391, beta=1.182952, expected_energy=-0.05926271
# gamma=4.260830, beta=1.183500, expected_energy=-0.05927416
# gamma=4.265755, beta=1.184365, expected_energy=-0.05929645
# gamma=4.275654, beta=1.185783, expected_energy=-0.05933972
# gamma=4.295613, beta=1.187069, expected_energy=-0.05942436
# gamma=4.335193, beta=1.181287, expected_energy=-0.05957152
# gamma=4.403532, beta=1.222876, expected_energy=-0.05943326
# gamma=4.348158, beta=1.143447, expected_energy=-0.05888769
# gamma=4.341437, beta=1.200287, expected_energy=-0.05955796
# gamma=4.344007, beta=1.176565, expected_energy=-0.05957263
# gamma=4.342396, beta=1.171832, expected_energy=-0.05951611
# gamma=4.345191, beta=1.176162, expected_energy=-0.05957352
# gamma=4.346143, beta=1.178473, expected_energy=-0.05959646
# gamma=4.348117, beta=1.183067, expected_energy=-0.05963078
# gamma=4.356701, beta=1.188197, expected_energy=-0.05967638
# gamma=4.358316, beta=1.198066, expected_energy=-0.05964886
# gamma=4.361130, beta=1.185876, expected_energy=-0.05969115
# gamma=4.363579, beta=1.181517, expected_energy=-0.05968370
# gamma=4.362219, beta=1.186488, expected_energy=-0.05969675
# gamma=4.363900, beta=1.188338, expected_energy=-0.05970543
# gamma=4.366358, beta=1.192693, expected_energy=-0.05970989
# gamma=4.362472, beta=1.195838, expected_energy=-0.05968059
# gamma=4.367447, beta=1.192078, expected_energy=-0.05971598
# gamma=4.369809, beta=1.191261, expected_energy=-0.05972738
# gamma=4.374596, beta=1.189814, expected_energy=-0.05974824
# gamma=4.384407, beta=1.187879, expected_energy=-0.05978663
# gamma=4.404360, beta=1.189240, expected_energy=-0.05986607
# gamma=4.444274, beta=1.191874, expected_energy=-0.06002045
# gamma=4.521512, beta=1.171037, expected_energy=-0.06011454
# gamma=4.552748, beta=1.244687, expected_energy=-0.05936321
# gamma=4.515846, beta=1.131441, expected_energy=-0.05883860
# gamma=4.531412, beta=1.169621, expected_energy=-0.06011964
# gamma=4.534561, beta=1.189371, expected_energy=-0.06034789
# gamma=4.538275, beta=1.209023, expected_energy=-0.06027313
# gamma=4.544114, beta=1.186416, expected_energy=-0.06036715
# gamma=4.545098, beta=1.181514, expected_energy=-0.06033205
# gamma=4.545340, beta=1.186662, expected_energy=-0.06037273
# gamma=4.546241, beta=1.188994, expected_energy=-0.06038709
# gamma=4.547750, beta=1.190988, expected_energy=-0.06039859
# gamma=4.546964, beta=1.195926, expected_energy=-0.06039756
# gamma=4.550230, beta=1.191303, expected_energy=-0.06040792
# gamma=4.552717, beta=1.191559, expected_energy=-0.06041714
# gamma=4.557694, beta=1.192036, expected_energy=-0.06043535
# gamma=4.567660, beta=1.192854, expected_energy=-0.06047132
# gamma=4.587631, beta=1.193934, expected_energy=-0.06054144
# gamma=4.627521, beta=1.190969, expected_energy=-0.06066741
# gamma=4.689449, beta=1.241614, expected_energy=-0.06006853
# gamma=4.633272, beta=1.151385, expected_energy=-0.05990239
# gamma=4.637417, beta=1.192407, expected_energy=-0.06070494
# gamma=4.638406, beta=1.212382, expected_energy=-0.06060885
# gamma=4.644101, beta=1.184968, expected_energy=-0.06067935
# gamma=4.639584, beta=1.196913, expected_energy=-0.06071828
# gamma=4.639033, beta=1.201882, expected_energy=-0.06070415
# gamma=6.197448, beta=1.229782, expected_energy=-0.06358703
# gamma=6.197624, beta=1.229773, expected_energy=-0.06358715
# gamma=6.197751, beta=1.229650, expected_energy=-0.06358714
# gamma=6.197688, beta=1.229851, expected_energy=-0.06358725
# gamma=6.197812, beta=1.230008, expected_energy=-0.06358742
# gamma=6.198024, beta=1.230346, expected_energy=-0.06358763
# gamma=6.197863, beta=1.230712, expected_energy=-0.06358751
# gamma=6.198224, beta=1.230363, expected_energy=-0.06358781
# gamma=6.198622, beta=1.230402, expected_energy=-0.06358801
# gamma=6.198968, beta=1.230203, expected_energy=-0.06358824
# gamma=6.199702, beta=1.229884, expected_energy=-0.06358855
# gamma=6.200294, beta=1.230422, expected_energy=-0.06358916
# gamma=6.201598, beta=1.231348, expected_energy=-0.06358964
# gamma=6.202879, beta=1.230389, expected_energy=-0.06359080
# gamma=6.205649, beta=1.228787, expected_energy=-0.06359091
# gamma=6.206489, beta=1.230149, expected_energy=-0.06359301
# gamma=6.208165, beta=1.232875, expected_energy=-0.06359172
# gamma=6.207391, beta=1.228828, expected_energy=-0.06359205
# gamma=6.206159, beta=1.229924, expected_energy=-0.06359273
# gamma=6.206698, beta=1.230921, expected_energy=-0.06359333
# gamma=6.206270, beta=1.231597, expected_energy=-0.06359256
# gamma=6.207098, beta=1.230910, expected_energy=-0.06359351
# gamma=6.207429, beta=1.231134, expected_energy=-0.06359367
# gamma=6.208214, beta=1.231291, expected_energy=-0.06359400
# gamma=6.209697, beta=1.231890, expected_energy=-0.06359450
# gamma=6.212208, beta=1.229907, expected_energy=-0.06359652
# gamma=6.217249, beta=1.225964, expected_energy=-0.06358788
# gamma=6.213377, beta=1.232886, expected_energy=-0.06359531
# gamma=6.212953, beta=1.229614, expected_energy=-0.06359666
# gamma=6.213021, beta=1.228016, expected_energy=-0.06359356
# gamma=6.213099, beta=1.229987, expected_energy=-0.06359714
# gamma=6.213491, beta=1.230684, expected_energy=-0.06359762
# gamma=6.214214, beta=1.231027, expected_energy=-0.06359810
# gamma=6.215403, beta=1.232097, expected_energy=-0.06359799
# gamma=6.214731, beta=1.230417, expected_energy=-0.06359841
# gamma=6.215156, beta=1.229739, expected_energy=-0.06359814
# gamma=6.214562, beta=1.230311, expected_energy=-0.06359827
# gamma=6.214950, beta=1.230752, expected_energy=-0.06359860
# gamma=6.215056, beta=1.231138, expected_energy=-0.06359861
# gamma=6.214864, beta=1.231195, expected_energy=-0.06359845
# gamma=6.215070, beta=1.231186, expected_energy=-0.06359864
# gamma=6.215163, beta=1.231223, expected_energy=-0.06359862
# gamma=6.215011, beta=1.231266, expected_energy=-0.06359858
#
# Optimization finished
# Best theta: [6.21507031 1.23118563]
# Best expected energy: -0.06359864285295108
# Success: True
# Message: Return from COBYLA because the trust region radius reaches its lower bound.

# %%
best_gamma = [float(result.x[0])]
best_beta  = [float(result.x[1])]

print("Best gamma:", best_gamma)
print("Best beta:", best_beta)
# Out:
# Best gamma: [6.2150703076625105]
# Best beta: [1.231185629614988]

# %%
main_opt = build_main_from_params(best_gamma, best_beta)
ket_opt = sim.state_vector(main_opt)
probs_opt = np.abs(np.array(ket_opt)) ** 2

top_k = 15
top_indices_opt = np.argsort(probs_opt)[::-1][:top_k]

print(f"Top {top_k} states after optimization:\n")
for rank, idx in enumerate(top_indices_opt, start=1):
    bitstring = format(idx, f"0{n_qubits}b")
    x_list = [int(b) for b in bitstring]
    energy = ising_energy_from_x_list(x_list, h8, J8, ising_offset)
    print(f"{rank:2d}. bitstring={bitstring}   prob={probs_opt[idx]:.8f}   energy={energy:.8f}")
# Out:
# Top 15 states after optimization:
#
#  1. bitstring=01111011   prob=0.01356722   energy=-0.11438400
#  2. bitstring=01111110   prob=0.01356298   energy=-0.14306000
#  3. bitstring=01101111   prob=0.01350694   energy=-0.05546400
#  4. bitstring=01110111   prob=0.01337634   energy=-0.05703200
#  5. bitstring=01111111   prob=0.01295645   energy=0.03233000
#  6. bitstring=01111101   prob=0.01294682   energy=-0.09982200
#  7. bitstring=00111111   prob=0.01273652   energy=-0.07715600
#  8. bitstring=01011111   prob=0.01250680   energy=-0.01557600
#  9. bitstring=01111010   prob=0.01212059   energy=-0.07643400
# 10. bitstring=01101011   prob=0.01098262   energy=-0.13817800
# 11. bitstring=01110011   prob=0.01087208   energy=-0.13972600
# 12. bitstring=01101110   prob=0.00998125   energy=-0.12419400
# 13. bitstring=01110110   prob=0.00988228   energy=-0.12575400
# 14. bitstring=10011111   prob=0.00966411   energy=-0.06678000
# 15. bitstring=01111001   prob=0.00949895   energy=-0.13986800

# %%
gt_index = int(ground_truth_bitstring, 2)

print("Ground-truth bitstring:", ground_truth_bitstring)
print("Ground-truth optimized probability:", probs_opt[gt_index])
print("Ground-truth Ising energy:", ising_energy_from_x_list(
    [int(b) for b in ground_truth_bitstring], h8, J8, ising_offset
))
# Out:
# Ground-truth bitstring: 11011110
# Ground-truth optimized probability: 0.007760842200114138
# Ground-truth Ising energy: -0.14326400000000006

# %% [markdown]
# **After some optimization runs and getting results we are ready for a "inference cell" or a unique cell where we can just tune p (depth of the circuit), the iterations, shots, etc.**

# %% [markdown]
# # **Inference cell**

# %% [markdown]
# **We start some tests for the 4 Assets - 2 qubits map first:**

# %% [markdown]
# # **Runs with COBYLA optimizer**

# %% [markdown]
# # **P = 1**

# %%
# - -- - -- - - THESE ARE THE CONFIGURATIONS YOU CAN TUNE - - -- - - 

P = 1             # DEPTH OF THE CIRCUIT, how much we repeat Hc and Hm gates or layers. if p=2 2 layers of hc and hm
MAXITER = 5000    # Maximum iterations for the classical optimizer "COBYLA" [MAXFUN TIMES log means we got to up this variable]
RHOBEG = 0.2      # Parameter for the classical optimizer or COBYLA, is the initial step size, how aggressive we do the classical optimizer
METHOD = "COBYLA" # The optimizer, we can (and should) change for other than COBYLA after 

# multiple initializations for the classical optimizer
INITIAL_POINTS = [
    ([0.3] * P, [0.2] * P),
    ([0.5] * P, [0.5] * P),
    ([1.0] * P, [0.5] * P),
    ([2.0] * P, [1.0] * P),
    ([np.pi / 2] * P, [np.pi / 4] * P),
]

TOP_K = 15       # How many States i print at the last report
SHOTS = 2000     # How much samples i want to simulate on the QAOA [shoots]
SEED = 123       # SEED for reproducibility
VERBOSE = False  # If i want to see every evaluation of the optimizer or no

# -------- build kernel + simulator from known variables --------
kernel = build_qaoa_ising_kernel(n_qubits, h_terms, J_terms) # WE BUILD THE QAOA CIRCUIT
sim = StackMemorySimulator(min_qubits=n_qubits)   # WE CREATE THE QUANTUM SIMULATOR

# -------- helper functions local to this cell --------

# We combine gamma and beta into theta for the Optimizer
def join_theta(gamma_vals, beta_vals):
    return np.array(list(gamma_vals) + list(beta_vals), dtype=float)

# We separate theta into gamma and beta for the QAOA
def split_theta(theta, p):
    theta = np.array(theta, dtype=float)
    gamma_vals = theta[:p].tolist()
    beta_vals = theta[p:2*p].tolist()
    return gamma_vals, beta_vals

# Function to calculate expected Ising energy. the final value sum of energy x probability. IS USED FOR THE OPTIMIZER
def expected_ising_energy_for_theta(theta):
    gamma_vals, beta_vals = split_theta(theta, P)
    main = build_main_from_params(gamma_vals, beta_vals)
    ket = sim.state_vector(main)
    probs = np.abs(np.array(ket)) ** 2

    exp_energy = 0.0
    for idx in range(2 ** n_qubits):
        bitstring = format(idx, f"0{n_qubits}b")
        x_list = [int(b) for b in bitstring]
        energy = ising_energy_from_x_list(x_list, h8, J8, ising_offset)
        exp_energy += probs[idx] * energy

    return float(exp_energy)

# We run 1 classic optimization
def optimize_once(theta0):
    eval_history = []

    def objective(theta):
        value = expected_ising_energy_for_theta(theta)
        eval_history.append((theta.copy(), value))
        if VERBOSE:
            g, b = split_theta(theta, P)
            print(f"gamma={np.round(g, 6)}, beta={np.round(b, 6)}, expected_energy={value:.8f}")
        return value

    result = minimize(
        objective,
        theta0,
        method=METHOD,
        options={"maxiter": MAXITER, "rhobeg": RHOBEG}
    )
    return result, eval_history

# Analysis wise function
def top_states_from_probs(probs, top_k=15):
    top_indices = np.argsort(probs)[::-1][:top_k]
    rows = []

    for rank, idx in enumerate(top_indices, start=1):
        bitstring = format(idx, f"0{n_qubits}b")
        x_list = [int(b) for b in bitstring]
        energy = ising_energy_from_x_list(x_list, h8, J8, ising_offset)
        rows.append({
            "rank": rank,
            "bitstring": bitstring,
            "prob": float(probs[idx]),
            "energy": float(energy),
        })
    return rows

def sample_counts_from_probs(probs, shots=1000, seed=123):
    rng = np.random.default_rng(seed)
    indices = np.arange(len(probs))
    probs = np.array(probs, dtype=float)
    probs = probs / probs.sum()
    sampled = rng.choice(indices, size=shots, p=probs)

    counts = {}
    for idx in sampled:
        bitstring = format(idx, f"0{n_qubits}b")
        counts[bitstring] = counts.get(bitstring, 0) + 1

    return dict(sorted(counts.items(), key=lambda kv: kv[1], reverse=True))

# -------- multi-start classical optimization --------
all_runs = []
best_result = None
best_history = None
best_theta0 = None

for run_id, (gamma0, beta0) in enumerate(INITIAL_POINTS, start=1):
    theta0 = join_theta(gamma0, beta0)
    result, history = optimize_once(theta0)
    all_runs.append({
        "run_id": run_id,
        "theta0": theta0,
        "result": result,
        "history": history
    })

    if best_result is None or result.fun < best_result.fun:
        best_result = result
        best_history = history
        best_theta0 = theta0

# -------- recover best params --------
best_gamma, best_beta = split_theta(best_result.x, P)

print("===================================")
print("BEST RUN SUMMARY")
print("===================================")
print("Initial theta:", best_theta0)
print("Best theta:", best_result.x)
print("Best gamma:", best_gamma)
print("Best beta:", best_beta)
print("Best expected energy:", best_result.fun)
print("Success:", best_result.success)
print("Message:", best_result.message)

# -------- evaluate final optimized circuit --------
main_opt = build_main_from_params(best_gamma, best_beta)
ket_opt = sim.state_vector(main_opt)
probs_opt = np.abs(np.array(ket_opt)) ** 2

# -------- top states --------
rows = top_states_from_probs(probs_opt, top_k=TOP_K)

print("\n===================================")
print(f"TOP {TOP_K} STATES AFTER OPTIMIZATION")
print("===================================")
for r in rows:
    print(f"{r['rank']:2d}. bitstring={r['bitstring']}   prob={r['prob']:.8f}   energy={r['energy']:.8f}")

# -------- ground truth info --------
gt_index = int(ground_truth_bitstring, 2)
gt_energy = ising_energy_from_x_list([int(b) for b in ground_truth_bitstring], h8, J8, ising_offset)

print("\n===================================")
print("GROUND TRUTH CHECK")
print("===================================")
print("Ground-truth bitstring:", ground_truth_bitstring)
print("Ground-truth probability:", probs_opt[gt_index])
print("Ground-truth energy:", gt_energy)

# -------- shot-based sampling --------
counts = sample_counts_from_probs(probs_opt, shots=SHOTS, seed=SEED)

print("\n===================================")
print(f"TOP 10 SAMPLED STATES ({SHOTS} shots)")
print("===================================")
for rank, (bitstring, count) in enumerate(list(counts.items())[:10], start=1):
    energy = ising_energy_from_x_list([int(b) for b in bitstring], h8, J8, ising_offset)
    print(f"{rank:2d}. bitstring={bitstring}   count={count}   freq={count/SHOTS:.6f}   energy={energy:.8f}")
# Out:
# ===================================
# BEST RUN SUMMARY
# ===================================
# Initial theta: [2. 1.]
# Best theta: [6.42593224 1.23418292]
# Best gamma: [6.425932239747539]
# Best beta: [1.2341829191756661]
# Best expected energy: -0.06370784169102113
# Success: True
# Message: Return from COBYLA because the trust region radius reaches its lower bound.
#
# ===================================
# TOP 15 STATES AFTER OPTIMIZATION
# ===================================
#  1. bitstring=01111011   prob=0.01386430   energy=-0.11438400
#  2. bitstring=01111110   prob=0.01385496   energy=-0.14306000
#  3. bitstring=01101111   prob=0.01379297   energy=-0.05546400
#  4. bitstring=01110111   prob=0.01365746   energy=-0.05703200
#  5. bitstring=01111111   prob=0.01325662   energy=0.03233000
#  6. bitstring=01111101   prob=0.01321751   energy=-0.09982200
#  7. bitstring=00111111   prob=0.01301763   energy=-0.07715600
#  8. bitstring=01011111   prob=0.01283870   energy=-0.01557600
#  9. bitstring=01111010   prob=0.01231771   energy=-0.07643400
# 10. bitstring=01101011   prob=0.01111996   energy=-0.13817800
# 11. bitstring=01110011   prob=0.01100611   energy=-0.13972600
# 12. bitstring=01101110   prob=0.01006808   energy=-0.12419400
# 13. bitstring=01110110   prob=0.00996651   energy=-0.12575400
# 14. bitstring=10011111   prob=0.00970378   energy=-0.06678000
# 15. bitstring=01111001   prob=0.00957635   energy=-0.13986800
#
# ===================================
# GROUND TRUTH CHECK
# ===================================
# Ground-truth bitstring: 11011110
# Ground-truth probability: 0.007779358479163642
# Ground-truth energy: -0.14326400000000006
#
# ===================================
# TOP 10 SAMPLED STATES (2000 shots)
# ===================================
#  1. bitstring=01110111   count=35   freq=0.017500   energy=-0.05703200
#  2. bitstring=01111011   count=34   freq=0.017000   energy=-0.11438400
#  3. bitstring=01111110   count=33   freq=0.016500   energy=-0.14306000
#  4. bitstring=00111111   count=29   freq=0.014500   energy=-0.07715600
#  5. bitstring=01011111   count=28   freq=0.014000   energy=-0.01557600
#  6. bitstring=01101011   count=27   freq=0.013500   energy=-0.13817800
#  7. bitstring=01111001   count=27   freq=0.013500   energy=-0.13986800
#  8. bitstring=01110011   count=27   freq=0.013500   energy=-0.13972600
#  9. bitstring=11011010   count=26   freq=0.013000   energy=-0.08730600
# 10. bitstring=11001111   count=24   freq=0.012000   energy=-0.04321200

# %% [markdown]
# # **P = 2**

# %%
# - -- - -- - - THESE ARE THE CONFIGURATIONS YOU CAN TUNE - - -- - - 

P = 2             # DEPTH OF THE CIRCUIT, how much we repeat Hc and Hm gates or layers. if p=2 2 layers of hc and hm
MAXITER = 5000    # Maximum iterations for the classical optimizer "COBYLA" [MAXFUN TIMES log means we got to up this variable]
RHOBEG = 0.2      # Parameter for the classical optimizer or COBYLA, is the initial step size, how aggressive we do the classical optimizer
METHOD = "COBYLA" # The optimizer, we can (and should) change for other than COBYLA after 

# multiple initializations for the classical optimizer
INITIAL_POINTS = [
    ([0.3, 0.3], [0.2, 0.2]),
    ([0.5, 0.5], [0.5, 0.5]),
    ([1.0, 0.5], [0.5, 0.25]),
    ([2.0, 1.0], [1.0, 0.5]),
    ([np.pi/2, np.pi/2], [np.pi/4, np.pi/4]),
]

TOP_K = 15       # How many States i print at the last report
SHOTS = 2000     # How much samples i want to simulate on the QAOA [shoots]
SEED = 123       # SEED for reproducibility
VERBOSE = False  # If i want to see every evaluation of the optimizer or no

# -------- build kernel + simulator from known variables --------
kernel = build_qaoa_ising_kernel(n_qubits, h_terms, J_terms) # WE BUILD THE QAOA CIRCUIT
sim = StackMemorySimulator(min_qubits=n_qubits)   # WE CREATE THE QUANTUM SIMULATOR

# -------- helper functions local to this cell --------

# We combine gamma and beta into theta for the Optimizer
def join_theta(gamma_vals, beta_vals):
    return np.array(list(gamma_vals) + list(beta_vals), dtype=float)

# We separate theta into gamma and beta for the QAOA
def split_theta(theta, p):
    theta = np.array(theta, dtype=float)
    gamma_vals = theta[:p].tolist()
    beta_vals = theta[p:2*p].tolist()
    return gamma_vals, beta_vals

# Function to calculate expected Ising energy. the final value sum of energy x probability. IS USED FOR THE OPTIMIZER
def expected_ising_energy_for_theta(theta):
    gamma_vals, beta_vals = split_theta(theta, P)
    main = build_main_from_params(gamma_vals, beta_vals)
    ket = sim.state_vector(main)
    probs = np.abs(np.array(ket)) ** 2

    exp_energy = 0.0
    for idx in range(2 ** n_qubits):
        bitstring = format(idx, f"0{n_qubits}b")
        x_list = [int(b) for b in bitstring]
        energy = ising_energy_from_x_list(x_list, h8, J8, ising_offset)
        exp_energy += probs[idx] * energy

    return float(exp_energy)

# We run 1 classic optimization
def optimize_once(theta0):
    eval_history = []

    def objective(theta):
        value = expected_ising_energy_for_theta(theta)
        eval_history.append((theta.copy(), value))
        if VERBOSE:
            g, b = split_theta(theta, P)
            print(f"gamma={np.round(g, 6)}, beta={np.round(b, 6)}, expected_energy={value:.8f}")
        return value

    result = minimize(
        objective,
        theta0,
        method=METHOD,
        options={"maxiter": MAXITER, "rhobeg": RHOBEG}
    )
    return result, eval_history

# Analysis wise function
def top_states_from_probs(probs, top_k=15):
    top_indices = np.argsort(probs)[::-1][:top_k]
    rows = []

    for rank, idx in enumerate(top_indices, start=1):
        bitstring = format(idx, f"0{n_qubits}b")
        x_list = [int(b) for b in bitstring]
        energy = ising_energy_from_x_list(x_list, h8, J8, ising_offset)
        rows.append({
            "rank": rank,
            "bitstring": bitstring,
            "prob": float(probs[idx]),
            "energy": float(energy),
        })
    return rows

def sample_counts_from_probs(probs, shots=1000, seed=123):
    rng = np.random.default_rng(seed)
    indices = np.arange(len(probs))
    probs = np.array(probs, dtype=float)
    probs = probs / probs.sum()
    sampled = rng.choice(indices, size=shots, p=probs)

    counts = {}
    for idx in sampled:
        bitstring = format(idx, f"0{n_qubits}b")
        counts[bitstring] = counts.get(bitstring, 0) + 1

    return dict(sorted(counts.items(), key=lambda kv: kv[1], reverse=True))

# -------- multi-start classical optimization --------
all_runs = []
best_result = None
best_history = None
best_theta0 = None

for run_id, (gamma0, beta0) in enumerate(INITIAL_POINTS, start=1):
    theta0 = join_theta(gamma0, beta0)
    result, history = optimize_once(theta0)
    all_runs.append({
        "run_id": run_id,
        "theta0": theta0,
        "result": result,
        "history": history
    })

    if best_result is None or result.fun < best_result.fun:
        best_result = result
        best_history = history
        best_theta0 = theta0

# -------- recover best params --------
best_gamma, best_beta = split_theta(best_result.x, P)

print("===================================")
print("BEST RUN SUMMARY")
print("===================================")
print("Initial theta:", best_theta0)
print("Best theta:", best_result.x)
print("Best gamma:", best_gamma)
print("Best beta:", best_beta)
print("Best expected energy:", best_result.fun)
print("Success:", best_result.success)
print("Message:", best_result.message)

# -------- evaluate final optimized circuit --------
main_opt = build_main_from_params(best_gamma, best_beta)
ket_opt = sim.state_vector(main_opt)
probs_opt = np.abs(np.array(ket_opt)) ** 2

# -------- top states --------
rows = top_states_from_probs(probs_opt, top_k=TOP_K)

print("\n===================================")
print(f"TOP {TOP_K} STATES AFTER OPTIMIZATION")
print("===================================")
for r in rows:
    print(f"{r['rank']:2d}. bitstring={r['bitstring']}   prob={r['prob']:.8f}   energy={r['energy']:.8f}")

# -------- ground truth info --------
gt_index = int(ground_truth_bitstring, 2)
gt_energy = ising_energy_from_x_list([int(b) for b in ground_truth_bitstring], h8, J8, ising_offset)

print("\n===================================")
print("GROUND TRUTH CHECK")
print("===================================")
print("Ground-truth bitstring:", ground_truth_bitstring)
print("Ground-truth probability:", probs_opt[gt_index])
print("Ground-truth energy:", gt_energy)

# -------- shot-based sampling --------
counts = sample_counts_from_probs(probs_opt, shots=SHOTS, seed=SEED)

print("\n===================================")
print(f"TOP 10 SAMPLED STATES ({SHOTS} shots)")
print("===================================")
for rank, (bitstring, count) in enumerate(list(counts.items())[:10], start=1):
    energy = ising_energy_from_x_list([int(b) for b in bitstring], h8, J8, ising_offset)
    print(f"{rank:2d}. bitstring={bitstring}   count={count}   freq={count/SHOTS:.6f}   energy={energy:.8f}")
# Out:
# ===================================
# BEST RUN SUMMARY
# ===================================
# Initial theta: [2.  1.  1.  0.5]
# Best theta: [2.65534514 4.88442119 0.73822424 1.04082835]
# Best gamma: [2.655345142905891, 4.884421191712956]
# Best beta: [0.7382242413227708, 1.0408283472736666]
# Best expected energy: -0.07549502499905696
# Success: True
# Message: Return from COBYLA because the trust region radius reaches its lower bound.
#
# ===================================
# TOP 15 STATES AFTER OPTIMIZATION
# ===================================
#  1. bitstring=01111111   prob=0.02048951   energy=0.03233000
#  2. bitstring=01111011   prob=0.01644220   energy=-0.11438400
#  3. bitstring=11011111   prob=0.01602258   energy=0.04989800
#  4. bitstring=10111111   prob=0.01554884   energy=-0.02954200
#  5. bitstring=11111111   prob=0.01530173   energy=0.10847200
#  6. bitstring=01111110   prob=0.01516613   energy=-0.14306000
#  7. bitstring=11111011   prob=0.01512554   energy=-0.08091000
#  8. bitstring=11101111   prob=0.01507408   energy=-0.00065800
#  9. bitstring=11111101   prob=0.01506098   energy=-0.05923600
# 10. bitstring=11111110   prob=0.01502587   energy=-0.13803000
# 11. bitstring=11110111   prob=0.01496694   energy=-0.00222600
# 12. bitstring=11111010   prob=0.01389641   energy=-0.11407200
# 13. bitstring=11101011   prob=0.01351161   energy=-0.12604000
# 14. bitstring=11110011   prob=0.01341402   energy=-0.12758800
# 15. bitstring=11011011   prob=0.01332238   energy=-0.10748400
#
# ===================================
# GROUND TRUTH CHECK
# ===================================
# Ground-truth bitstring: 11011110
# Ground-truth probability: 0.012469279781989922
# Ground-truth energy: -0.14326400000000006
#
# ===================================
# TOP 10 SAMPLED STATES (2000 shots)
# ===================================
#  1. bitstring=01111111   count=46   freq=0.023000   energy=0.03233000
#  2. bitstring=11111110   count=39   freq=0.019500   energy=-0.13803000
#  3. bitstring=01111011   count=37   freq=0.018500   energy=-0.11438400
#  4. bitstring=11111010   count=37   freq=0.018500   energy=-0.11407200
#  5. bitstring=01111110   count=34   freq=0.017000   energy=-0.14306000
#  6. bitstring=11101110   count=33   freq=0.016500   energy=-0.14050000
#  7. bitstring=01111101   count=31   freq=0.015500   energy=-0.09982200
#  8. bitstring=11001111   count=31   freq=0.015500   energy=-0.04321200
#  9. bitstring=10111111   count=30   freq=0.015000   energy=-0.02954200
# 10. bitstring=11111101   count=30   freq=0.015000   energy=-0.05923600

# %% [markdown]
# # **P = 3**

# %%
# - -- - -- - - THESE ARE THE CONFIGURATIONS YOU CAN TUNE - - -- - - 

P = 3             # DEPTH OF THE CIRCUIT
MAXITER = 5000     # Start conservative for P=3
RHOBEG = 0.2
METHOD = "COBYLA"

INITIAL_POINTS = [
    ([0.3, 0.3, 0.3], [0.2, 0.2, 0.2]),
    ([0.5, 0.5, 0.5], [0.5, 0.5, 0.5]),
    ([1.0, 0.7, 0.4], [0.5, 0.35, 0.2]),
    ([2.0, 1.0, 0.5], [1.0, 0.5, 0.25]),
    ([np.pi/2, np.pi/2, np.pi/2], [np.pi/4, np.pi/4, np.pi/4]),
]

TOP_K = 15       # How many States i print at the last report
SHOTS = 2000     # How much samples i want to simulate on the QAOA [shoots]
SEED = 123       # SEED for reproducibility
VERBOSE = False  # If i want to see every evaluation of the optimizer or no

# -------- build kernel + simulator from known variables --------
kernel = build_qaoa_ising_kernel(n_qubits, h_terms, J_terms) # WE BUILD THE QAOA CIRCUIT
sim = StackMemorySimulator(min_qubits=n_qubits)   # WE CREATE THE QUANTUM SIMULATOR

# -------- helper functions local to this cell --------

# We combine gamma and beta into theta for the Optimizer
def join_theta(gamma_vals, beta_vals):
    return np.array(list(gamma_vals) + list(beta_vals), dtype=float)

# We separate theta into gamma and beta for the QAOA
def split_theta(theta, p):
    theta = np.array(theta, dtype=float)
    gamma_vals = theta[:p].tolist()
    beta_vals = theta[p:2*p].tolist()
    return gamma_vals, beta_vals

# Function to calculate expected Ising energy. the final value sum of energy x probability. IS USED FOR THE OPTIMIZER
def expected_ising_energy_for_theta(theta):
    gamma_vals, beta_vals = split_theta(theta, P)
    main = build_main_from_params(gamma_vals, beta_vals)
    ket = sim.state_vector(main)
    probs = np.abs(np.array(ket)) ** 2

    exp_energy = 0.0
    for idx in range(2 ** n_qubits):
        bitstring = format(idx, f"0{n_qubits}b")
        x_list = [int(b) for b in bitstring]
        energy = ising_energy_from_x_list(x_list, h8, J8, ising_offset)
        exp_energy += probs[idx] * energy

    return float(exp_energy)

# We run 1 classic optimization
def optimize_once(theta0):
    eval_history = []

    def objective(theta):
        value = expected_ising_energy_for_theta(theta)
        eval_history.append((theta.copy(), value))
        if VERBOSE:
            g, b = split_theta(theta, P)
            print(f"gamma={np.round(g, 6)}, beta={np.round(b, 6)}, expected_energy={value:.8f}")
        return value

    result = minimize(
        objective,
        theta0,
        method=METHOD,
        options={"maxiter": MAXITER, "rhobeg": RHOBEG}
    )
    return result, eval_history

# Analysis wise function
def top_states_from_probs(probs, top_k=15):
    top_indices = np.argsort(probs)[::-1][:top_k]
    rows = []

    for rank, idx in enumerate(top_indices, start=1):
        bitstring = format(idx, f"0{n_qubits}b")
        x_list = [int(b) for b in bitstring]
        energy = ising_energy_from_x_list(x_list, h8, J8, ising_offset)
        rows.append({
            "rank": rank,
            "bitstring": bitstring,
            "prob": float(probs[idx]),
            "energy": float(energy),
        })
    return rows

def sample_counts_from_probs(probs, shots=1000, seed=123):
    rng = np.random.default_rng(seed)
    indices = np.arange(len(probs))
    probs = np.array(probs, dtype=float)
    probs = probs / probs.sum()
    sampled = rng.choice(indices, size=shots, p=probs)

    counts = {}
    for idx in sampled:
        bitstring = format(idx, f"0{n_qubits}b")
        counts[bitstring] = counts.get(bitstring, 0) + 1

    return dict(sorted(counts.items(), key=lambda kv: kv[1], reverse=True))

# -------- multi-start classical optimization --------
all_runs = []
best_result = None
best_history = None
best_theta0 = None

for run_id, (gamma0, beta0) in enumerate(INITIAL_POINTS, start=1):
    theta0 = join_theta(gamma0, beta0)
    result, history = optimize_once(theta0)
    all_runs.append({
        "run_id": run_id,
        "theta0": theta0,
        "result": result,
        "history": history
    })

    if best_result is None or result.fun < best_result.fun:
        best_result = result
        best_history = history
        best_theta0 = theta0

# -------- recover best params --------
best_gamma, best_beta = split_theta(best_result.x, P)

print("===================================")
print("BEST RUN SUMMARY")
print("===================================")
print("Initial theta:", best_theta0)
print("Best theta:", best_result.x)
print("Best gamma:", best_gamma)
print("Best beta:", best_beta)
print("Best expected energy:", best_result.fun)
print("Success:", best_result.success)
print("Message:", best_result.message)

# -------- evaluate final optimized circuit --------
main_opt = build_main_from_params(best_gamma, best_beta)
ket_opt = sim.state_vector(main_opt)
probs_opt = np.abs(np.array(ket_opt)) ** 2

# -------- top states --------
rows = top_states_from_probs(probs_opt, top_k=TOP_K)

print("\n===================================")
print(f"TOP {TOP_K} STATES AFTER OPTIMIZATION")
print("===================================")
for r in rows:
    print(f"{r['rank']:2d}. bitstring={r['bitstring']}   prob={r['prob']:.8f}   energy={r['energy']:.8f}")

# -------- ground truth info --------
gt_index = int(ground_truth_bitstring, 2)
gt_energy = ising_energy_from_x_list([int(b) for b in ground_truth_bitstring], h8, J8, ising_offset)

print("\n===================================")
print("GROUND TRUTH CHECK")
print("===================================")
print("Ground-truth bitstring:", ground_truth_bitstring)
print("Ground-truth probability:", probs_opt[gt_index])
print("Ground-truth energy:", gt_energy)

# -------- shot-based sampling --------
counts = sample_counts_from_probs(probs_opt, shots=SHOTS, seed=SEED)

print("\n===================================")
print(f"TOP 10 SAMPLED STATES ({SHOTS} shots)")
print("===================================")
for rank, (bitstring, count) in enumerate(list(counts.items())[:10], start=1):
    energy = ising_energy_from_x_list([int(b) for b in bitstring], h8, J8, ising_offset)
    print(f"{rank:2d}. bitstring={bitstring}   count={count}   freq={count/SHOTS:.6f}   energy={energy:.8f}")
# Out:
# ===================================
# BEST RUN SUMMARY
# ===================================
# Initial theta: [1.   0.7  0.4  0.5  0.35 0.2 ]
# Best theta: [ 2.86991436  3.47316165  2.29781715  0.76482887 -0.31694054  1.27068039]
# Best gamma: [2.869914364079031, 3.473161654753224, 2.2978171547706787]
# Best beta: [0.7648288661326326, -0.3169405407687838, 1.2706803895095498]
# Best expected energy: -0.07657993406457808
# Success: True
# Message: Return from COBYLA because the trust region radius reaches its lower bound.
#
# ===================================
# TOP 15 STATES AFTER OPTIMIZATION
# ===================================
#  1. bitstring=01111111   prob=0.02031951   energy=0.03233000
#  2. bitstring=01111011   prob=0.01664606   energy=-0.11438400
#  3. bitstring=11011111   prob=0.01597978   energy=0.04989800
#  4. bitstring=01111110   prob=0.01535745   energy=-0.14306000
#  5. bitstring=10111111   prob=0.01531491   energy=-0.02954200
#  6. bitstring=11111101   prob=0.01434909   energy=-0.05923600
#  7. bitstring=11011011   prob=0.01400711   energy=-0.10748400
#  8. bitstring=10111011   prob=0.01387264   energy=-0.13358400
#  9. bitstring=11101111   prob=0.01372274   energy=-0.00065800
# 10. bitstring=11110111   prob=0.01360026   energy=-0.00222600
# 11. bitstring=11101011   prob=0.01354719   energy=-0.12604000
# 12. bitstring=11111001   prob=0.01352850   energy=-0.14195000
# 13. bitstring=11110011   prob=0.01342490   energy=-0.12758800
# 14. bitstring=11101110   prob=0.01333968   energy=-0.14050000
# 15. bitstring=10111110   prob=0.01326918   energy=-0.13382400
#
# ===================================
# GROUND TRUTH CHECK
# ===================================
# Ground-truth bitstring: 11011110
# Ground-truth probability: 0.013244965407274604
# Ground-truth energy: -0.14326400000000006
#
# ===================================
# TOP 10 SAMPLED STATES (2000 shots)
# ===================================
#  1. bitstring=01111111   count=46   freq=0.023000   energy=0.03233000
#  2. bitstring=01111110   count=42   freq=0.021000   energy=-0.14306000
#  3. bitstring=11111110   count=37   freq=0.018500   energy=-0.13803000
#  4. bitstring=10111110   count=34   freq=0.017000   energy=-0.13382400
#  5. bitstring=11111100   count=32   freq=0.016000   energy=-0.12793800
#  6. bitstring=11111001   count=31   freq=0.015500   energy=-0.14195000
#  7. bitstring=11011011   count=31   freq=0.015500   energy=-0.10748400
#  8. bitstring=10111111   count=29   freq=0.014500   energy=-0.02954200
#  9. bitstring=11110101   count=28   freq=0.014000   energy=-0.11659400
# 10. bitstring=10111010   count=28   freq=0.014000   energy=-0.02452600

# %% [markdown]
# # **Plots**

# %%
import pandas as pd

experiment_results = [
    {
        "label": "4f-2q, P=1",
        "P": 1,
        "best_expected_energy": -0.06370784169102113,
        "best_gamma": [6.425932239747539],
        "best_beta": [1.2341829191756661],
        "top1_bitstring": "01111011",
        "top1_prob": 0.01386430,
        "top1_energy": -0.11438400,
        "best_low_energy_seen_bitstring": "01111110",
        "best_low_energy_seen_energy": -0.14306000,
        "runtime_min": 3 + 12.3/60,
    },
    {
        "label": "4f-2q, P=2",
        "P": 2,
        "best_expected_energy": -0.07549502499905696,
        "best_gamma": [2.655345142905891, 4.884421191712956],
        "best_beta": [0.7382242413227708, 1.0408283472736666],
        "top1_bitstring": "01111111",
        "top1_prob": 0.02048951,
        "top1_energy": 0.03233000,
        "best_low_energy_seen_bitstring": "01111110",
        "best_low_energy_seen_energy": -0.14306000,
        "runtime_min": 17 + 9.7/60,
    },
    {
        "label": "4f-2q, P=3",
        "P": 3,
        "best_expected_energy": -0.07657993406457808,
        "best_gamma": [2.869914364079031, 3.473161654753224, 2.2978171547706787],
        "best_beta": [0.7648288661326326, -0.3169405407687838, 1.2706803895095498],
        "top1_bitstring": "01111111",
        "top1_prob": 0.02031951,
        "top1_energy": 0.03233000,
        "best_low_energy_seen_bitstring": "01111110",
        "best_low_energy_seen_energy": -0.14306000,
        "runtime_min": 21 + 8.3/60,
    },
]

df_results = pd.DataFrame(experiment_results)
df_results
# Out:
#         label  P  best_expected_energy  \
# 0  4f-2q, P=1  1             -0.063708
# 1  4f-2q, P=2  2             -0.075495
# 2  4f-2q, P=3  3             -0.076580
#
#                                           best_gamma  \
# 0                                [6.425932239747539]
# 1             [2.655345142905891, 4.884421191712956]
# 2  [2.869914364079031, 3.473161654753224, 2.29781...
#
#                                            best_beta top1_bitstring  \
# 0                               [1.2341829191756661]       01111011
# 1           [0.7382242413227708, 1.0408283472736666]       01111111
# 2  [0.7648288661326326, -0.3169405407687838, 1.27...       01111111
#
#    top1_prob  top1_energy best_low_energy_seen_bitstring  \
# 0   0.013864    -0.114384                       01111110
# 1   0.020490     0.032330                       01111110
# 2   0.020320     0.032330                       01111110
#
#    best_low_energy_seen_energy  runtime_min
# 0                     -0.14306     3.205000
# 1                     -0.14306    17.161667
# 2                     -0.14306    21.138333

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(8, 4.5))

ax1.plot(df_results["P"], df_results["best_expected_energy"], marker="o")
ax1.set_xlabel("QAOA depth P")
ax1.set_ylabel("Best expected Ising energy")
ax1.grid(True)

ax2 = ax1.twinx()
ax2.plot(df_results["P"], df_results["runtime_min"], marker="s", linestyle="--")
ax2.set_ylabel("Runtime (minutes)")

plt.title("QAOA quality vs runtime")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 4))
plt.plot(df_results["P"], df_results["best_expected_energy"], marker="o")
plt.xlabel("QAOA depth P")
plt.ylabel("Best expected Ising energy")
plt.title("Best expected energy vs QAOA depth")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(7, 4))
plt.plot(df_results["P"], df_results["runtime_min"], marker="o")
plt.xlabel("QAOA depth P")
plt.ylabel("Runtime (minutes)")
plt.title("Runtime vs QAOA depth")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(7, 4))
plt.bar(df_results["label"], df_results["top1_prob"])
plt.ylabel("Top-1 state probability")
plt.title("Top-1 state probability by experiment")
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Runs with POWELL optimizer**

# %% [markdown]
# # **P = 1**

# %%
# - -- - -- - - THESE ARE THE CONFIGURATIONS YOU CAN TUNE - - -- - - 

P = 1             # DEPTH OF THE CIRCUIT, how much we repeat Hc and Hm gates or layers. if p=2 2 layers of hc and hm
MAXITER = 5000    # Maximum iterations for the classical optimizer "COBYLA" [MAXFUN TIMES log means we got to up this variable]
RHOBEG = 0.2      # Parameter for the classical optimizer or COBYLA, is the initial step size, how aggressive we do the classical optimizer
METHOD = "Powell" # The optimizer, we can (and should) change for other than COBYLA after 

# multiple initializations for the classical optimizer
INITIAL_POINTS = [
    ([0.3] * P, [0.2] * P),
    ([0.5] * P, [0.5] * P),
    ([1.0] * P, [0.5] * P),
    ([2.0] * P, [1.0] * P),
    ([np.pi / 2] * P, [np.pi / 4] * P),
]

TOP_K = 15       # How many States i print at the last report
SHOTS = 2000     # How much samples i want to simulate on the QAOA [shoots]
SEED = 123       # SEED for reproducibility
VERBOSE = False  # If i want to see every evaluation of the optimizer or no

# -------- build kernel + simulator from known variables --------
kernel = build_qaoa_ising_kernel(n_qubits, h_terms, J_terms) # WE BUILD THE QAOA CIRCUIT
sim = StackMemorySimulator(min_qubits=n_qubits)   # WE CREATE THE QUANTUM SIMULATOR

# -------- helper functions local to this cell --------

# We combine gamma and beta into theta for the Optimizer
def join_theta(gamma_vals, beta_vals):
    return np.array(list(gamma_vals) + list(beta_vals), dtype=float)

# We separate theta into gamma and beta for the QAOA
def split_theta(theta, p):
    theta = np.array(theta, dtype=float)
    gamma_vals = theta[:p].tolist()
    beta_vals = theta[p:2*p].tolist()
    return gamma_vals, beta_vals

# Function to calculate expected Ising energy. the final value sum of energy x probability. IS USED FOR THE OPTIMIZER
def expected_ising_energy_for_theta(theta):
    gamma_vals, beta_vals = split_theta(theta, P)
    main = build_main_from_params(gamma_vals, beta_vals)
    ket = sim.state_vector(main)
    probs = np.abs(np.array(ket)) ** 2

    exp_energy = 0.0
    for idx in range(2 ** n_qubits):
        bitstring = format(idx, f"0{n_qubits}b")
        x_list = [int(b) for b in bitstring]
        energy = ising_energy_from_x_list(x_list, h8, J8, ising_offset)
        exp_energy += probs[idx] * energy

    return float(exp_energy)

# We run 1 classic optimization
def optimize_once(theta0):
    eval_history = []

    def objective(theta):
        value = expected_ising_energy_for_theta(theta)
        eval_history.append((theta.copy(), value))
        if VERBOSE:
            g, b = split_theta(theta, P)
            print(f"gamma={np.round(g, 6)}, beta={np.round(b, 6)}, expected_energy={value:.8f}")
        return value

    result = minimize(
        objective,
        theta0,
        method=METHOD,
        options={"maxiter": MAXITER, "rhobeg": RHOBEG}
    )
    return result, eval_history

# Analysis wise function
def top_states_from_probs(probs, top_k=15):
    top_indices = np.argsort(probs)[::-1][:top_k]
    rows = []

    for rank, idx in enumerate(top_indices, start=1):
        bitstring = format(idx, f"0{n_qubits}b")
        x_list = [int(b) for b in bitstring]
        energy = ising_energy_from_x_list(x_list, h8, J8, ising_offset)
        rows.append({
            "rank": rank,
            "bitstring": bitstring,
            "prob": float(probs[idx]),
            "energy": float(energy),
        })
    return rows

def sample_counts_from_probs(probs, shots=1000, seed=123):
    rng = np.random.default_rng(seed)
    indices = np.arange(len(probs))
    probs = np.array(probs, dtype=float)
    probs = probs / probs.sum()
    sampled = rng.choice(indices, size=shots, p=probs)

    counts = {}
    for idx in sampled:
        bitstring = format(idx, f"0{n_qubits}b")
        counts[bitstring] = counts.get(bitstring, 0) + 1

    return dict(sorted(counts.items(), key=lambda kv: kv[1], reverse=True))

# -------- multi-start classical optimization --------
all_runs = []
best_result = None
best_history = None
best_theta0 = None

for run_id, (gamma0, beta0) in enumerate(INITIAL_POINTS, start=1):
    theta0 = join_theta(gamma0, beta0)
    result, history = optimize_once(theta0)
    all_runs.append({
        "run_id": run_id,
        "theta0": theta0,
        "result": result,
        "history": history
    })

    if best_result is None or result.fun < best_result.fun:
        best_result = result
        best_history = history
        best_theta0 = theta0

# -------- recover best params --------
best_gamma, best_beta = split_theta(best_result.x, P)

print("===================================")
print("BEST RUN SUMMARY")
print("===================================")
print("Initial theta:", best_theta0)
print("Best theta:", best_result.x)
print("Best gamma:", best_gamma)
print("Best beta:", best_beta)
print("Best expected energy:", best_result.fun)
print("Success:", best_result.success)
print("Message:", best_result.message)

# -------- evaluate final optimized circuit --------
main_opt = build_main_from_params(best_gamma, best_beta)
ket_opt = sim.state_vector(main_opt)
probs_opt = np.abs(np.array(ket_opt)) ** 2

# -------- top states --------
rows = top_states_from_probs(probs_opt, top_k=TOP_K)

print("\n===================================")
print(f"TOP {TOP_K} STATES AFTER OPTIMIZATION")
print("===================================")
for r in rows:
    print(f"{r['rank']:2d}. bitstring={r['bitstring']}   prob={r['prob']:.8f}   energy={r['energy']:.8f}")

# -------- ground truth info --------
gt_index = int(ground_truth_bitstring, 2)
gt_energy = ising_energy_from_x_list([int(b) for b in ground_truth_bitstring], h8, J8, ising_offset)

print("\n===================================")
print("GROUND TRUTH CHECK")
print("===================================")
print("Ground-truth bitstring:", ground_truth_bitstring)
print("Ground-truth probability:", probs_opt[gt_index])
print("Ground-truth energy:", gt_energy)

# -------- shot-based sampling --------
counts = sample_counts_from_probs(probs_opt, shots=SHOTS, seed=SEED)

print("\n===================================")
print(f"TOP 10 SAMPLED STATES ({SHOTS} shots)")
print("===================================")
for rank, (bitstring, count) in enumerate(list(counts.items())[:10], start=1):
    energy = ising_energy_from_x_list([int(b) for b in bitstring], h8, J8, ising_offset)
    print(f"{rank:2d}. bitstring={bitstring}   count={count}   freq={count/SHOTS:.6f}   energy={energy:.8f}")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_32432\2995701818.py:67: OptimizeWarning: Unknown solver options: rhobeg
#   result = minimize(
# ===================================
# BEST RUN SUMMARY
# ===================================
# Initial theta: [1.  0.5]
# Best theta: [6.84929933 1.24060529]
# Best gamma: [6.849299327226156]
# Best beta: [1.2406052868560025]
# Best expected energy: -0.06379014874829884
# Success: True
# Message: Optimization terminated successfully.
#
# ===================================
# TOP 15 STATES AFTER OPTIMIZATION
# ===================================
#  1. bitstring=01111011   prob=0.01438615   energy=-0.11438400
#  2. bitstring=01111110   prob=0.01437079   energy=-0.14306000
#  3. bitstring=01101111   prob=0.01430401   energy=-0.05546400
#  4. bitstring=01110111   prob=0.01415952   energy=-0.05703200
#  5. bitstring=01111111   prob=0.01377580   energy=0.03233000
#  6. bitstring=01111101   prob=0.01370616   energy=-0.09982200
#  7. bitstring=00111111   prob=0.01353340   energy=-0.07715600
#  8. bitstring=01011111   prob=0.01347327   energy=-0.01557600
#  9. bitstring=01111010   prob=0.01266060   energy=-0.07643400
# 10. bitstring=01101011   prob=0.01135149   energy=-0.13817800
# 11. bitstring=01110011   prob=0.01123175   energy=-0.13972600
# 12. bitstring=01101110   prob=0.01020441   energy=-0.12419400
# 13. bitstring=01110110   prob=0.01009832   energy=-0.12575400
# 14. bitstring=10011111   prob=0.00972814   energy=-0.06678000
# 15. bitstring=01111001   prob=0.00969678   energy=-0.13986800
#
# ===================================
# GROUND TRUTH CHECK
# ===================================
# Ground-truth bitstring: 11011110
# Ground-truth probability: 0.007768444312821619
# Ground-truth energy: -0.14326400000000006
#
# ===================================
# TOP 10 SAMPLED STATES (2000 shots)
# ===================================
#  1. bitstring=01110111   count=38   freq=0.019000   energy=-0.05703200
#  2. bitstring=01111011   count=35   freq=0.017500   energy=-0.11438400
#  3. bitstring=01111111   count=31   freq=0.015500   energy=0.03233000
#  4. bitstring=01111010   count=29   freq=0.014500   energy=-0.07643400
#  5. bitstring=01111101   count=29   freq=0.014500   energy=-0.09982200
#  6. bitstring=01110011   count=28   freq=0.014000   energy=-0.13972600
#  7. bitstring=01011111   count=28   freq=0.014000   energy=-0.01557600
#  8. bitstring=10110011   count=26   freq=0.013000   energy=-0.13759400
#  9. bitstring=01101111   count=25   freq=0.012500   energy=-0.05546400
# 10. bitstring=01101011   count=25   freq=0.012500   energy=-0.13817800

# %% [markdown]
# # **P = 2**

# %%
# - -- - -- - - THESE ARE THE CONFIGURATIONS YOU CAN TUNE - - -- - - 

P = 2             # DEPTH OF THE CIRCUIT, how much we repeat Hc and Hm gates or layers. if p=2 2 layers of hc and hm
MAXITER = 5000    # Maximum iterations for the classical optimizer "COBYLA" [MAXFUN TIMES log means we got to up this variable]
RHOBEG = 0.2      # Parameter for the classical optimizer or COBYLA, is the initial step size, how aggressive we do the classical optimizer
METHOD = "Powell" # The optimizer, we can (and should) change for other than COBYLA after 

# multiple initializations for the classical optimizer
INITIAL_POINTS = [
    ([0.3, 0.3], [0.2, 0.2]),
    ([0.5, 0.5], [0.5, 0.5]),
    ([1.0, 0.5], [0.5, 0.25]),
    ([2.0, 1.0], [1.0, 0.5]),
    ([np.pi/2, np.pi/2], [np.pi/4, np.pi/4]),
]

TOP_K = 15       # How many States i print at the last report
SHOTS = 2000     # How much samples i want to simulate on the QAOA [shoots]
SEED = 123       # SEED for reproducibility
VERBOSE = False  # If i want to see every evaluation of the optimizer or no

# -------- build kernel + simulator from known variables --------
kernel = build_qaoa_ising_kernel(n_qubits, h_terms, J_terms) # WE BUILD THE QAOA CIRCUIT
sim = StackMemorySimulator(min_qubits=n_qubits)   # WE CREATE THE QUANTUM SIMULATOR

# -------- helper functions local to this cell --------

# We combine gamma and beta into theta for the Optimizer
def join_theta(gamma_vals, beta_vals):
    return np.array(list(gamma_vals) + list(beta_vals), dtype=float)

# We separate theta into gamma and beta for the QAOA
def split_theta(theta, p):
    theta = np.array(theta, dtype=float)
    gamma_vals = theta[:p].tolist()
    beta_vals = theta[p:2*p].tolist()
    return gamma_vals, beta_vals

# Function to calculate expected Ising energy. the final value sum of energy x probability. IS USED FOR THE OPTIMIZER
def expected_ising_energy_for_theta(theta):
    gamma_vals, beta_vals = split_theta(theta, P)
    main = build_main_from_params(gamma_vals, beta_vals)
    ket = sim.state_vector(main)
    probs = np.abs(np.array(ket)) ** 2

    exp_energy = 0.0
    for idx in range(2 ** n_qubits):
        bitstring = format(idx, f"0{n_qubits}b")
        x_list = [int(b) for b in bitstring]
        energy = ising_energy_from_x_list(x_list, h8, J8, ising_offset)
        exp_energy += probs[idx] * energy

    return float(exp_energy)

# We run 1 classic optimization
def optimize_once(theta0):
    eval_history = []

    def objective(theta):
        value = expected_ising_energy_for_theta(theta)
        eval_history.append((theta.copy(), value))
        if VERBOSE:
            g, b = split_theta(theta, P)
            print(f"gamma={np.round(g, 6)}, beta={np.round(b, 6)}, expected_energy={value:.8f}")
        return value

    result = minimize(
        objective,
        theta0,
        method=METHOD,
        options={"maxiter": MAXITER, "rhobeg": RHOBEG}
    )
    return result, eval_history

# Analysis wise function
def top_states_from_probs(probs, top_k=15):
    top_indices = np.argsort(probs)[::-1][:top_k]
    rows = []

    for rank, idx in enumerate(top_indices, start=1):
        bitstring = format(idx, f"0{n_qubits}b")
        x_list = [int(b) for b in bitstring]
        energy = ising_energy_from_x_list(x_list, h8, J8, ising_offset)
        rows.append({
            "rank": rank,
            "bitstring": bitstring,
            "prob": float(probs[idx]),
            "energy": float(energy),
        })
    return rows

def sample_counts_from_probs(probs, shots=1000, seed=123):
    rng = np.random.default_rng(seed)
    indices = np.arange(len(probs))
    probs = np.array(probs, dtype=float)
    probs = probs / probs.sum()
    sampled = rng.choice(indices, size=shots, p=probs)

    counts = {}
    for idx in sampled:
        bitstring = format(idx, f"0{n_qubits}b")
        counts[bitstring] = counts.get(bitstring, 0) + 1

    return dict(sorted(counts.items(), key=lambda kv: kv[1], reverse=True))

# -------- multi-start classical optimization --------
all_runs = []
best_result = None
best_history = None
best_theta0 = None

for run_id, (gamma0, beta0) in enumerate(INITIAL_POINTS, start=1):
    theta0 = join_theta(gamma0, beta0)
    result, history = optimize_once(theta0)
    all_runs.append({
        "run_id": run_id,
        "theta0": theta0,
        "result": result,
        "history": history
    })

    if best_result is None or result.fun < best_result.fun:
        best_result = result
        best_history = history
        best_theta0 = theta0

# -------- recover best params --------
best_gamma, best_beta = split_theta(best_result.x, P)

print("===================================")
print("BEST RUN SUMMARY")
print("===================================")
print("Initial theta:", best_theta0)
print("Best theta:", best_result.x)
print("Best gamma:", best_gamma)
print("Best beta:", best_beta)
print("Best expected energy:", best_result.fun)
print("Success:", best_result.success)
print("Message:", best_result.message)

# -------- evaluate final optimized circuit --------
main_opt = build_main_from_params(best_gamma, best_beta)
ket_opt = sim.state_vector(main_opt)
probs_opt = np.abs(np.array(ket_opt)) ** 2

# -------- top states --------
rows = top_states_from_probs(probs_opt, top_k=TOP_K)

print("\n===================================")
print(f"TOP {TOP_K} STATES AFTER OPTIMIZATION")
print("===================================")
for r in rows:
    print(f"{r['rank']:2d}. bitstring={r['bitstring']}   prob={r['prob']:.8f}   energy={r['energy']:.8f}")

# -------- ground truth info --------
gt_index = int(ground_truth_bitstring, 2)
gt_energy = ising_energy_from_x_list([int(b) for b in ground_truth_bitstring], h8, J8, ising_offset)

print("\n===================================")
print("GROUND TRUTH CHECK")
print("===================================")
print("Ground-truth bitstring:", ground_truth_bitstring)
print("Ground-truth probability:", probs_opt[gt_index])
print("Ground-truth energy:", gt_energy)

# -------- shot-based sampling --------
counts = sample_counts_from_probs(probs_opt, shots=SHOTS, seed=SEED)

print("\n===================================")
print(f"TOP 10 SAMPLED STATES ({SHOTS} shots)")
print("===================================")
for rank, (bitstring, count) in enumerate(list(counts.items())[:10], start=1):
    energy = ising_energy_from_x_list([int(b) for b in bitstring], h8, J8, ising_offset)
    print(f"{rank:2d}. bitstring={bitstring}   count={count}   freq={count/SHOTS:.6f}   energy={energy:.8f}")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_32432\3235100387.py:67: OptimizeWarning: Unknown solver options: rhobeg
#   result = minimize(
# ===================================
# BEST RUN SUMMARY
# ===================================
# Initial theta: [1.   0.5  0.5  0.25]
# Best theta: [ 3.84884639 28.87948093  1.16336919  0.34300864]
# Best gamma: [3.848846385644849, 28.879480926439392]
# Best beta: [1.1633691922371248, 0.3430086443982931]
# Best expected energy: -0.08076194629595579
# Success: True
# Message: Optimization terminated successfully.
#
# ===================================
# TOP 15 STATES AFTER OPTIMIZATION
# ===================================
#  1. bitstring=01011111   prob=0.04089387   energy=-0.01557600
#  2. bitstring=00111111   prob=0.03846998   energy=-0.07715600
#  3. bitstring=10011101   prob=0.03837446   energy=-0.13670800
#  4. bitstring=01111101   prob=0.03287217   energy=-0.09982200
#  5. bitstring=10011111   prob=0.02824846   energy=-0.06678000
#  6. bitstring=11100101   prob=0.02362085   energy=-0.14038400
#  7. bitstring=11100111   prob=0.02342944   energy=-0.07935600
#  8. bitstring=01111111   prob=0.02200890   energy=0.03233000
#  9. bitstring=10110101   prob=0.02083424   energy=-0.14082800
# 10. bitstring=10101101   prob=0.02022140   energy=-0.13926000
# 11. bitstring=01111011   prob=0.01998045   energy=-0.11438400
# 12. bitstring=01111110   prob=0.01970397   energy=-0.14306000
# 13. bitstring=11100110   prob=0.01921570   energy=-0.11253000
# 14. bitstring=10010111   prob=0.01796283   energy=-0.11881000
# 15. bitstring=01110111   prob=0.01781451   energy=-0.05703200
#
# ===================================
# GROUND TRUTH CHECK
# ===================================
# Ground-truth bitstring: 11011110
# Ground-truth probability: 0.0012233043629380528
# Ground-truth energy: -0.14326400000000006
#
# ===================================
# TOP 10 SAMPLED STATES (2000 shots)
# ===================================
#  1. bitstring=01011111   count=87   freq=0.043500   energy=-0.01557600
#  2. bitstring=10011101   count=78   freq=0.039000   energy=-0.13670800
#  3. bitstring=00111111   count=73   freq=0.036500   energy=-0.07715600
#  4. bitstring=01111101   count=65   freq=0.032500   energy=-0.09982200
#  5. bitstring=01111011   count=52   freq=0.026000   energy=-0.11438400
#  6. bitstring=10011111   count=49   freq=0.024500   energy=-0.06678000
#  7. bitstring=01110111   count=45   freq=0.022500   energy=-0.05703200
#  8. bitstring=11100110   count=45   freq=0.022500   energy=-0.11253000
#  9. bitstring=10010111   count=43   freq=0.021500   energy=-0.11881000
# 10. bitstring=01111111   count=42   freq=0.021000   energy=0.03233000

# %% [markdown]
# # **P = 3**

# %%
# - -- - -- - - THESE ARE THE CONFIGURATIONS YOU CAN TUNE - - -- - - 

P = 3             # DEPTH OF THE CIRCUIT
MAXITER = 5000     # Start conservative for P=3
RHOBEG = 0.2
METHOD = "Powell"

INITIAL_POINTS = [
    ([0.3, 0.3, 0.3], [0.2, 0.2, 0.2]),
    ([0.5, 0.5, 0.5], [0.5, 0.5, 0.5]),
    ([1.0, 0.7, 0.4], [0.5, 0.35, 0.2]),
    ([2.0, 1.0, 0.5], [1.0, 0.5, 0.25]),
    ([np.pi/2, np.pi/2, np.pi/2], [np.pi/4, np.pi/4, np.pi/4]),
]

TOP_K = 15       # How many States i print at the last report
SHOTS = 2000     # How much samples i want to simulate on the QAOA [shoots]
SEED = 123       # SEED for reproducibility
VERBOSE = False  # If i want to see every evaluation of the optimizer or no

# -------- build kernel + simulator from known variables --------
kernel = build_qaoa_ising_kernel(n_qubits, h_terms, J_terms) # WE BUILD THE QAOA CIRCUIT
sim = StackMemorySimulator(min_qubits=n_qubits)   # WE CREATE THE QUANTUM SIMULATOR

# -------- helper functions local to this cell --------

# We combine gamma and beta into theta for the Optimizer
def join_theta(gamma_vals, beta_vals):
    return np.array(list(gamma_vals) + list(beta_vals), dtype=float)

# We separate theta into gamma and beta for the QAOA
def split_theta(theta, p):
    theta = np.array(theta, dtype=float)
    gamma_vals = theta[:p].tolist()
    beta_vals = theta[p:2*p].tolist()
    return gamma_vals, beta_vals

# Function to calculate expected Ising energy. the final value sum of energy x probability. IS USED FOR THE OPTIMIZER
def expected_ising_energy_for_theta(theta):
    gamma_vals, beta_vals = split_theta(theta, P)
    main = build_main_from_params(gamma_vals, beta_vals)
    ket = sim.state_vector(main)
    probs = np.abs(np.array(ket)) ** 2

    exp_energy = 0.0
    for idx in range(2 ** n_qubits):
        bitstring = format(idx, f"0{n_qubits}b")
        x_list = [int(b) for b in bitstring]
        energy = ising_energy_from_x_list(x_list, h8, J8, ising_offset)
        exp_energy += probs[idx] * energy

    return float(exp_energy)

# We run 1 classic optimization
def optimize_once(theta0):
    eval_history = []

    def objective(theta):
        value = expected_ising_energy_for_theta(theta)
        eval_history.append((theta.copy(), value))
        if VERBOSE:
            g, b = split_theta(theta, P)
            print(f"gamma={np.round(g, 6)}, beta={np.round(b, 6)}, expected_energy={value:.8f}")
        return value

    result = minimize(
        objective,
        theta0,
        method=METHOD,
        options={"maxiter": MAXITER, "rhobeg": RHOBEG}
    )
    return result, eval_history

# Analysis wise function
def top_states_from_probs(probs, top_k=15):
    top_indices = np.argsort(probs)[::-1][:top_k]
    rows = []

    for rank, idx in enumerate(top_indices, start=1):
        bitstring = format(idx, f"0{n_qubits}b")
        x_list = [int(b) for b in bitstring]
        energy = ising_energy_from_x_list(x_list, h8, J8, ising_offset)
        rows.append({
            "rank": rank,
            "bitstring": bitstring,
            "prob": float(probs[idx]),
            "energy": float(energy),
        })
    return rows

def sample_counts_from_probs(probs, shots=1000, seed=123):
    rng = np.random.default_rng(seed)
    indices = np.arange(len(probs))
    probs = np.array(probs, dtype=float)
    probs = probs / probs.sum()
    sampled = rng.choice(indices, size=shots, p=probs)

    counts = {}
    for idx in sampled:
        bitstring = format(idx, f"0{n_qubits}b")
        counts[bitstring] = counts.get(bitstring, 0) + 1

    return dict(sorted(counts.items(), key=lambda kv: kv[1], reverse=True))

# -------- multi-start classical optimization --------
all_runs = []
best_result = None
best_history = None
best_theta0 = None

for run_id, (gamma0, beta0) in enumerate(INITIAL_POINTS, start=1):
    theta0 = join_theta(gamma0, beta0)
    result, history = optimize_once(theta0)
    all_runs.append({
        "run_id": run_id,
        "theta0": theta0,
        "result": result,
        "history": history
    })

    if best_result is None or result.fun < best_result.fun:
        best_result = result
        best_history = history
        best_theta0 = theta0

# -------- recover best params --------
best_gamma, best_beta = split_theta(best_result.x, P)

print("===================================")
print("BEST RUN SUMMARY")
print("===================================")
print("Initial theta:", best_theta0)
print("Best theta:", best_result.x)
print("Best gamma:", best_gamma)
print("Best beta:", best_beta)
print("Best expected energy:", best_result.fun)
print("Success:", best_result.success)
print("Message:", best_result.message)

# -------- evaluate final optimized circuit --------
main_opt = build_main_from_params(best_gamma, best_beta)
ket_opt = sim.state_vector(main_opt)
probs_opt = np.abs(np.array(ket_opt)) ** 2

# -------- top states --------
rows = top_states_from_probs(probs_opt, top_k=TOP_K)

print("\n===================================")
print(f"TOP {TOP_K} STATES AFTER OPTIMIZATION")
print("===================================")
for r in rows:
    print(f"{r['rank']:2d}. bitstring={r['bitstring']}   prob={r['prob']:.8f}   energy={r['energy']:.8f}")

# -------- ground truth info --------
gt_index = int(ground_truth_bitstring, 2)
gt_energy = ising_energy_from_x_list([int(b) for b in ground_truth_bitstring], h8, J8, ising_offset)

print("\n===================================")
print("GROUND TRUTH CHECK")
print("===================================")
print("Ground-truth bitstring:", ground_truth_bitstring)
print("Ground-truth probability:", probs_opt[gt_index])
print("Ground-truth energy:", gt_energy)

# -------- shot-based sampling --------
counts = sample_counts_from_probs(probs_opt, shots=SHOTS, seed=SEED)

print("\n===================================")
print(f"TOP 10 SAMPLED STATES ({SHOTS} shots)")
print("===================================")
for rank, (bitstring, count) in enumerate(list(counts.items())[:10], start=1):
    energy = ising_energy_from_x_list([int(b) for b in bitstring], h8, J8, ising_offset)
    print(f"{rank:2d}. bitstring={bitstring}   count={count}   freq={count/SHOTS:.6f}   energy={energy:.8f}")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_32432\1171803897.py:66: OptimizeWarning: Unknown solver options: rhobeg
#   result = minimize(
# ===================================
# BEST RUN SUMMARY
# ===================================
# Initial theta: [0.5 0.5 0.5 0.5 0.5 0.5]
# Best theta: [ 3.77874974 12.25333977 -6.64385014  0.73123468  0.14693858  0.9608266 ]
# Best gamma: [3.778749744455954, 12.253339769511252, -6.643850137793278]
# Best beta: [0.7312346769475571, 0.14693858260443848, 0.9608266013108241]
# Best expected energy: -0.08466262153502388
# Success: True
# Message: Optimization terminated successfully.
#
# ===================================
# TOP 15 STATES AFTER OPTIMIZATION
# ===================================
#  1. bitstring=01111110   prob=0.01700576   energy=-0.14306000
#  2. bitstring=01111011   prob=0.01679502   energy=-0.11438400
#  3. bitstring=11011011   prob=0.01656020   energy=-0.10748400
#  4. bitstring=11011110   prob=0.01643197   energy=-0.14326400
#  5. bitstring=01101111   prob=0.01566154   energy=-0.05546400
#  6. bitstring=10111110   prob=0.01566121   energy=-0.13382400
#  7. bitstring=10111011   prob=0.01555151   energy=-0.13358400
#  8. bitstring=01110111   prob=0.01552471   energy=-0.05703200
#  9. bitstring=01111010   prob=0.01542809   energy=-0.07643400
# 10. bitstring=11001111   prob=0.01513714   energy=-0.04321200
# 11. bitstring=11010111   prob=0.01504163   energy=-0.04480000
# 12. bitstring=10101111   prob=0.01493126   energy=-0.09600400
# 13. bitstring=10110111   prob=0.01483901   energy=-0.09757200
# 14. bitstring=11101101   prob=0.01455770   energy=-0.11502600
# 15. bitstring=11111100   prob=0.01448365   energy=-0.12793800
#
# ===================================
# GROUND TRUTH CHECK
# ===================================
# Ground-truth bitstring: 11011110
# Ground-truth probability: 0.0164319736429234
# Ground-truth energy: -0.14326400000000006
#
# ===================================
# TOP 10 SAMPLED STATES (2000 shots)
# ===================================
#  1. bitstring=01111110   count=42   freq=0.021000   energy=-0.14306000
#  2. bitstring=10111101   count=39   freq=0.019500   energy=-0.12613800
#  3. bitstring=11011011   count=36   freq=0.018000   energy=-0.10748400
#  4. bitstring=11001111   count=36   freq=0.018000   energy=-0.04321200
#  5. bitstring=01111011   count=34   freq=0.017000   energy=-0.11438400
#  6. bitstring=11111100   count=34   freq=0.017000   energy=-0.12793800
#  7. bitstring=11010111   count=33   freq=0.016500   energy=-0.04480000
#  8. bitstring=11110101   count=32   freq=0.016000   energy=-0.11659400
#  9. bitstring=11110010   count=32   freq=0.016000   energy=-0.05408200
# 10. bitstring=10111010   count=32   freq=0.016000   energy=-0.02452600

# %% [markdown]
# # **Ploting**

# %%
import pandas as pd

experiment_results = [
    {
        "label": "Powell, 4f-2q, P=1",
        "optimizer": "Powell",
        "P": 1,
        "best_expected_energy": -0.06379014874829884,
        "best_gamma": [6.849299327226156],
        "best_beta": [1.2406052868560025],
        "top1_bitstring": "01111011",
        "top1_prob": 0.01438615,
        "top1_energy": -0.11438400,
        "best_low_energy_seen_bitstring": "01111110",
        "best_low_energy_seen_energy": -0.14306000,
        "runtime_min": 34.8 / 60,
    },
    {
        "label": "Powell, 4f-2q, P=2",
        "optimizer": "Powell",
        "P": 2,
        "best_expected_energy": -0.08076194629595579,
        "best_gamma": [3.848846385644849, 28.879480926439392],
        "best_beta": [1.1633691922371248, 0.3430086443982931],
        "top1_bitstring": "01011111",
        "top1_prob": 0.04089387,
        "top1_energy": -0.01557600,
        "best_low_energy_seen_bitstring": "10011101",
        "best_low_energy_seen_energy": -0.13670800,
        "runtime_min": 2 + 50.1 / 60,
    },
    {
        "label": "Powell, 4f-2q, P=3",
        "optimizer": "Powell",
        "P": 3,
        "best_expected_energy": -0.08466262153502388,
        "best_gamma": [3.778749744455954, 12.253339769511252, -6.643850137793278],
        "best_beta": [0.7312346769475571, 0.14693858260443848, 0.9608266013108241],
        "top1_bitstring": "01111110",
        "top1_prob": 0.01700576,
        "top1_energy": -0.14306000,
        "best_low_energy_seen_bitstring": "11011110",
        "best_low_energy_seen_energy": -0.14326400,
        "runtime_min": 10 + 23.0 / 60,
    },
]

df_results = pd.DataFrame(experiment_results)
df_results
# Out:
#                 label optimizer  P  best_expected_energy  \
# 0  Powell, 4f-2q, P=1    Powell  1             -0.063790
# 1  Powell, 4f-2q, P=2    Powell  2             -0.080762
# 2  Powell, 4f-2q, P=3    Powell  3             -0.084663
#
#                                           best_gamma  \
# 0                                [6.849299327226156]
# 1            [3.848846385644849, 28.879480926439392]
# 2  [3.778749744455954, 12.253339769511252, -6.643...
#
#                                            best_beta top1_bitstring  \
# 0                               [1.2406052868560025]       01111011
# 1           [1.1633691922371248, 0.3430086443982931]       01011111
# 2  [0.7312346769475571, 0.14693858260443848, 0.96...       01111110
#
#    top1_prob  top1_energy best_low_energy_seen_bitstring  \
# 0   0.014386    -0.114384                       01111110
# 1   0.040894    -0.015576                       10011101
# 2   0.017006    -0.143060                       11011110
#
#    best_low_energy_seen_energy  runtime_min
# 0                    -0.143060     0.580000
# 1                    -0.136708     2.835000
# 2                    -0.143264    10.383333

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(8, 4.5))

ax1.plot(df_results["P"], df_results["best_expected_energy"], marker="o")
ax1.set_xlabel("QAOA depth P")
ax1.set_ylabel("Best expected Ising energy")
ax1.grid(True)

ax2 = ax1.twinx()
ax2.plot(df_results["P"], df_results["runtime_min"], marker="s", linestyle="--")
ax2.set_ylabel("Runtime (minutes)")

plt.title("Powell QAOA: quality vs runtime")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 4))
plt.plot(df_results["P"], df_results["best_expected_energy"], marker="o")
plt.xlabel("QAOA depth P")
plt.ylabel("Best expected Ising energy")
plt.title("Powell: best expected energy vs QAOA depth")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(7, 4))
plt.plot(df_results["P"], df_results["runtime_min"], marker="o")
plt.xlabel("QAOA depth P")
plt.ylabel("Runtime (minutes)")
plt.title("Powell: runtime vs QAOA depth")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(7, 4))
plt.bar(df_results["label"], df_results["top1_prob"])
plt.ylabel("Top-1 state probability")
plt.title("Powell: top-1 state probability")
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Probability Graphs**

# %%
import pandas as pd

df_prob = pd.DataFrame([
    {
        "label": "Powell, P=1",
        "P": 1,
        "ground_truth_probability": 0.007768444312821619,
        "top1_bitstring": "01111011",
        "top1_probability": 0.01438615,
        "top1_energy": -0.11438400,
    },
    {
        "label": "Powell, P=2",
        "P": 2,
        "ground_truth_probability": 0.0012233043629380528,
        "top1_bitstring": "01011111",
        "top1_probability": 0.04089387,
        "top1_energy": -0.01557600,
    },
    {
        "label": "Powell, P=3",
        "P": 3,
        "ground_truth_probability": 0.0164319736429234,
        "top1_bitstring": "01111110",
        "top1_probability": 0.01700576,
        "top1_energy": -0.14306000,
    },
])

df_prob
# Out:
#          label  P  ground_truth_probability top1_bitstring  top1_probability  \
# 0  Powell, P=1  1                  0.007768       01111011          0.014386
# 1  Powell, P=2  2                  0.001223       01011111          0.040894
# 2  Powell, P=3  3                  0.016432       01111110          0.017006
#
#    top1_energy
# 0    -0.114384
# 1    -0.015576
# 2    -0.143060

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,4))
plt.plot(df_prob["P"], df_prob["ground_truth_probability"], marker="o")
plt.xlabel("QAOA depth P")
plt.ylabel("Ground-truth probability")
plt.title("Powell: probability of the ground-truth bitstring vs QAOA depth")
plt.grid(True)
plt.show()

# %%
import numpy as np

x = np.arange(len(df_prob))
w = 0.35

plt.figure(figsize=(8,4))
plt.bar(x - w/2, df_prob["ground_truth_probability"], width=w, label="Ground truth")
plt.bar(x + w/2, df_prob["top1_probability"], width=w, label="Top-1 state")

plt.xticks(x, df_prob["label"], rotation=20)
plt.ylabel("Probability")
plt.title("Powell: ground-truth vs top-1 probability")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Qubit probability Graphs**

# %%
import numpy as np
import matplotlib.pyplot as plt

def qubit_marginal_probs(probs, n_qubits):
    p1 = np.zeros(n_qubits)
    for idx, p in enumerate(probs):
        bitstring = format(idx, f"0{n_qubits}b")
        for i, b in enumerate(bitstring):
            if b == "1":
                p1[i] += p
    return p1

p1 = qubit_marginal_probs(probs_opt, n_qubits)

plt.figure(figsize=(9,4.5))
bars = plt.bar([f"q{i}" for i in range(n_qubits)], p1)

for i, v in enumerate(p1):
    plt.text(i, v + 0.015, f"{v:.3f}", ha="center")

plt.ylabel("P(qubit = 1)")
plt.xlabel("Qubit")
plt.title("Powell, 4f-2q, P=3: Marginal probability of measuring 1 on each qubit")
plt.ylim(0, 1)
plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# This is to represent individual qubits but it losses correlation between qubits ^

# %%
import numpy as np
import matplotlib.pyplot as plt

def pair_state_probs(probs, n_qubits):
    pair_probs = []
    n_pairs = n_qubits // 2

    for pair_idx in range(n_pairs):
        counts = {"00": 0.0, "01": 0.0, "10": 0.0, "11": 0.0}

        q0 = 2 * pair_idx
        q1 = 2 * pair_idx + 1

        for idx, p in enumerate(probs):
            bitstring = format(idx, f"0{n_qubits}b")
            pair_bits = bitstring[q0] + bitstring[q1]
            counts[pair_bits] += p

        pair_probs.append(counts)

    return pair_probs

pair_probs = pair_state_probs(probs_opt, n_qubits)

fig, axes = plt.subplots(1, 4, figsize=(14,4), sharey=True)

for a in range(4):
    labels = list(pair_probs[a].keys())
    vals = list(pair_probs[a].values())
    axes[a].bar(labels, vals)
    axes[a].set_title(f"Asset {a+1}")
    axes[a].set_ylim(0, 1)
    axes[a].set_xlabel("2-qubit state")
    if a == 0:
        axes[a].set_ylabel("Probability")

plt.suptitle("Powell, 4f-2q, P=3: Probability distribution over 2-qubit states per asset")
plt.tight_layout()
plt.show()

# %% [markdown]
# This one actually does not interpret aisled qubits and it represents 2 qubits per asset so we are taking correlation into consideration ^
